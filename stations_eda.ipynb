# %%
# !head output.csv
# Out:
# ,circle_coordinates,circle_name,closest_coordinates,closest_station
# 0,"(41.869061, -71.032434)",Taunton-Middleboro,"(41.87556, -71.02111)","TAUNTON MUNICIPAL AIRPORT, MA US"
# 1,"(42.3833, -71.1667)",Belmont,"(42.38333, -71.11667)","CAMBRIDGE, MA US"
# 2,"(42.3833, -71.1667)",Belmont,"(42.38333, -71.11667)","CAMBRIDGE, MA US"
# 3,"(40.9333, -73.1167)",L.I.: Setauket,"(40.9256, -73.0997)","SETAUKET EAST SETAUKET 0.3 SSE, NY US"
# 4,"(40.1, -75.5833)",Merlin,"(40.08333, -75.55)","DEVAULT 1 W, PA US"
# 5,"(41.5, -90.5167)",Moline,"(41.4885, -90.5084)","MOLINE 1.0 WNW, IL US"
# 6,"(41.869061, -71.032434)",Taunton-Middleboro,"(41.87556, -71.02111)","TAUNTON MUNICIPAL AIRPORT, MA US"
# 7,"(39.966731, -75.600001)",West Chester,"(39.9708, -75.635)","WEST CHESTER 2 NW, PA US"
# 8,"(42.3833, -71.1667)",Belmont,"(42.38333, -71.11667)","CAMBRIDGE, MA US"

# %%
import os
import sys
import csv
import collections
import json

# %%
unique_closest_station = {}
total_records = 0

with open("output.csv") as csvfile:
    reader = csv.DictReader(csvfile, delimiter=",")
    for row in reader:
        total_records += 1
        unique_closest_station[row['closest_station']] = unique_closest_station.get(row['closest_station'], 0) + 1

# %%
len(unique_closest_station)
# Out:
# 5094

# %%
sorted(unique_closest_station.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('ROCHESTER 3.4 NNW, NY US', 133),
#  ('NY CITY CENTRAL PARK, NY US', 133),
#  ('CADIZ 2, OH US', 118),
#  ('BATTLE CREEK 5 NW, MI US', 118),
#  ('READING 2.9 ESE, PA US', 117),
#  ('STATEN ISLAND 1.4 SE, NY US', 116),
#  ('WEST CHESTER 2 NW, PA US', 112),
#  ('WESTPORT, CA', 110),
#  ('INDIANAPOLIS 10.0 NE, IN US', 109),
#  ('PRINCETON WATER WORK, NJ US', 108),
#  ('WESTMINSTER, CA', 107),
#  ('CAMERON HELIPORT, LA US', 107),
#  ('GENEVA EXPERIMENT ST, NY US', 106),
#  ('WHITE LAKE 3.2 N, MI US', 106),
#  ('BENNINGTON MORSE STATE AIRPORT, VT US', 106),
#  ('GRAND ISLAND, NY US', 105),
#  ('GREENPORT POWER HOUS, NY US', 104),
#  ('NEW LONDON 1.0 NNW, CT US', 103),
#  ('NEW ROCHELLE 1.3 S, NY US', 102),
#  ('HARTFORD, CT US', 101),
#  ('NASHVILLE 11.2 SW, TN US', 101),
#  ('LITITZ 4.5 N, PA US', 100),
#  ('SIOUX CITY 0.7 NW, IA US', 100),
#  ('NETHER PROVIDENCE TOWNSHIP 0.4, PA US', 98),
#  ('SYRACUSE HANCOCK INTERNATIONAL AIRPORT, NY US', 98),
#  ('WINDSOR HEIGHTS 0.8 SE, IA US', 98),
#  ('LITTLETON 6.0 WSW, CO US', 98),
#  ('PORTLAND KGW TV, OR US', 98),
#  ('FORT PLAIN 0.2 SE, NY US', 98),
#  ('LOWER TWP 2.2 NE, NJ US', 98),
#  ('CULVER CITY, CA US', 96),
#  ('WYNCOTE 0.3 ENE, PA US', 95),
#  ('CHULA VISTA, CA US', 95),
#  ('ALEXANDRIA 2.4 NE, VA US', 95),
#  ('SALEM 1.0 NNE, OH US', 95),
#  ('ANN ARBOR NEAR, MI US', 95),
#  ('PENSACOLA 1.9 NE, FL US', 95),
#  ('BUCKEYE LAKE 1 N, OH US', 95),
#  ('WICHITA, KS US', 94),
#  ('TOLEDO BLADE, OH US', 94),
#  ('HAMILTON 2, OH US', 94),
#  ('HAMILTON, CA', 94),
#  ('DAYTON 6.7 NNW, OH US', 94),
#  ('OTTAWA U OF O, CA', 93),
#  ('NEW HAVEN, CT US', 93),
#  ('SEATTLE CITY OFFICE, WA US', 93),
#  ('MONTAUK, NY US', 92),
#  ('RICHMOND HEIGHTS 0.4 NNE, OH US', 92),
#  ('SETAUKET EAST SETAUKET 0.3 SSE, NY US', 91),
#  ('SCHENECTADY 5.6 SSW, NY US', 91),
#  ('ROSEMOUNT 0.3 W, OH US', 91),
#  ('WEST LAFAYETTE 0.9 N, IN US', 90),
#  ('APPLETON 0.9 W, WI US', 89),
#  ('HARWICH 2.9 NE, MA US', 89),
#  ('STEVENSON DAM, CT US', 89),
#  ('MEMPHIS 5.5 ENE, TN US', 89),
#  ('NEW YORK BENSONHURST, NY US', 88),
#  ('BELMONT 0.3 SE, MA US', 88),
#  ('MADISON WEATHER BUREAU CITY, WI US', 88),
#  ('COLUMBUS NAS, OH US', 88),
#  ('CHAPEL HILL 2 W, NC US', 88),
#  ('UNITY VILLAGE, MO US', 87),
#  ('GLOUCESTER 1.2 WSW, MA US', 87),
#  ('SPOKANE 5.0 N, WA US', 87),
#  ('BETTENDORF 1.6 WSW, IA US', 87),
#  ('BOWLING GREEN 3.7 S, KY US', 87),
#  ('MONTEREY 1.1 SSW, CA US', 87),
#  ('PARSIPPANY TROY HILLS TWP 2.1, NJ US', 86),
#  ('SANTA BARBARA 3.0 W, CA US', 86),
#  ('SPRINGFIELD, IL US', 86),
#  ('KINGSVILLE, OH US', 85),
#  ('ELSAH PRINCIPIA COL, IL US', 85),
#  ('ST. PETERSBURG 4.5 NW, FL US', 85),
#  ('OCEAN TWP 2.1 WSW, NJ US', 84),
#  ('SHOREWOOD, WI US', 84),
#  ('OLD BROWNSBORO PLACE 0.3 SW, KY US', 84),
#  ('CAMP HILL, PA US', 84),
#  ('YANKTON 1.7 NNE, SD US', 84),
#  ('LITTLE EGG HARBOR TWP 5.4 N, NJ US', 84),
#  ('LANCASTER, OH US', 84),
#  ('NORTHAMPTON 1.6 NE, MA US', 84),
#  ('BOGOTA ELDORADO, CO', 84),
#  ('JACKSONVILLE 10.2 ENE, FL US', 83),
#  ('WILLIAMS BAY, WI US', 83),
#  ('BAYTOWN 1.0 ENE, TX US', 83),
#  ('FORT WORTH NAS, TX US', 83),
#  ('SCRANTON, PA US', 83),
#  ('HAMBURG 0.3 ESE, NY US', 82),
#  ('MOUNTVILLE 0.5 NW, PA US', 82),
#  ('COTE ST LUC, CA', 82),
#  ('VESTAVIA HILLS 2.4 NE, AL US', 82),
#  ('CENTERVILLE 0.3 N, IN US', 81),
#  ('MOUNT LAUREL TWP 0.5 WSW, NJ US', 81),
#  ('FARGO HECTOR INTERNATIONAL AIRPORT, ND US', 81),
#  ('DOUSMAN 3.2 SSE, WI US', 81),
#  ('MORAVIA 2.5 ESE, NY US', 81),
#  ('EAST NANTMEAL 1.0 SSW, PA US', 81),
#  ('TUCSON 11.8 ENE, AZ US', 81),
#  ('OXFORD, OH US', 81),
#  ('CORAL BAY, US', 81),
#  ('COON RAPIDS 1.4 ESE, MN US', 80),
#  ('MOUNT PLEASANT 7.9 NNE, SC US', 80),
#  ('SANTA CLARA 3.1 ESE, CA US', 80),
#  ('BALDWIN 1.3 S, NY US', 80),
#  ('LINCOLN 3.9 W, NE US', 79),
#  ('BOZEMAN 6 W EXPERIMENTAL FARM, MT US', 79),
#  ('CRAWFORDVILLE 4.7 SE, FL US', 79),
#  ('NORMAN 2.8 NNE, OK US', 79),
#  ('ASHLAND, OH US', 79),
#  ('HELLERTOWN 2.9 ENE, PA US', 78),
#  ('SIOUX FALLS, SD US', 78),
#  ('PECATONICA 1.9 NE, IL US', 78),
#  ('FORT MORGAN 3.7 NNW, CO US', 78),
#  ('QUEBEC 2, CA', 78),
#  ('FAIRVIEW PARK 1.4 NE, OH US', 78),
#  ('KINGSTON 2.4 SW, RI US', 78),
#  ('YOSEMITE PARK HEADQUARTERS, CA US', 78),
#  ('SALT LAKE CITY, UT US', 78),
#  ('METUCHEN 0.5 E, NJ US', 78),
#  ('DOVER 6.0 WNW, DE US', 78),
#  ('DUBUQUE 1.4 WSW, IA US', 78),
#  ('STOW 4 SE, OH US', 78),
#  ('BOALSBURG 1.0 NNW, PA US', 78),
#  ('MIDWAY 12.7 ESE, GA US', 78),
#  ('BOULDER 1.3 NW, CO US', 77),
#  ('SUMMERSIDE 2.1 SE, OH US', 77),
#  ('AIKEN 8.3 E, SC US', 77),
#  ('WAUKEGAN, IL US', 77),
#  ('JAMESTOWN WATERWORKS, NY US', 77),
#  ('FREE UNION, VA US', 77),
#  ('SOUTHWEST HARBOR 0.3 NW, ME US', 77),
#  ('MUSKEGON 2.5 WSW, MI US', 77),
#  ('DEXTER 1.5 SE, NY US', 77),
#  ('UPHAM 3 N, ND US', 77),
#  ('EUGENE 3.6 WNW, OR US', 76),
#  ('VIRGINIA BEACH 3.8 SSE, VA US', 76),
#  ('PAKENHAM 7.8 NNW, CA', 76),
#  ('CENTROPOLIS 5 NE, KS US', 76),
#  ('BRICK TWP 2.4 SSW, NJ ', 76),
#  ('KNOXVILLE 8.0 WSW, TN US', 75),
#  ('DAVISON ARMY AIR FIELD, VA US', 75),
#  ('KALAMAZOO, MI US', 75),
#  ('BISMARCK 0.6 NNW, ND US', 75),
#  ('TOPEKA, KS US', 75),
#  ('OKLAHOMA CITY 6.7 NW, OK US', 75),
#  ('WOOSTER 4.8 SW, OH US', 75),
#  ('PIEDMONT 1.0 SE, CA US', 75),
#  ('WINSTON SALEM 1.4 SSW, NC US', 75),
#  ('WARREN, PA US', 75),
#  ('CHARLOTTE 3.9 WNW, NC US', 75),
#  ('GREAT SALT PLAINS DAM, OK US', 75),
#  ('WILBUR HYDRO POWER, TN US', 75),
#  ('BURLINGTON 0.4 W, VT US', 74),
#  ('FORT WAYNE 8.5 N, IN US', 74),
#  ('RALEIGH 3.8 SSW, NC US', 74),
#  ('FLORAL PARK 0.4 W, NY US', 74),
#  ('CAP AU GRIS LOCK AND DAM 25, MO US', 74),
#  ('GREEN BAY 5.3 SSW, WI US', 74),
#  ('BILLINGS 6.9 ENE CLOSED, MT US', 74),
#  ('SOUTH BEND 1.5 NE, IN US', 74),
#  ('NEW PROVIDENCE 0.8 ESE, NJ US', 74),
#  ('ANCIENT OAKS 2.3 WNW, PA US', 74),
#  ('SHREWSBURY 1.6 NNE, MA US', 73),
#  ('COLORADO SPRINGS 2.8 SSE, CO US', 73),
#  ('SAN GABRIEL, CA US', 73),
#  ('NORTH LIBERTY 1.0 ENE, IA US', 73),
#  ('FORT COLLINS 5.0 N, CO US', 73),
#  ('NORTH SHENANGO, PA US', 73),
#  ('KENMARE 1 WSW, ND US', 73),
#  ('BLENHEIM 9.8 E, CA', 73),
#  ('WILMINGTON 4.6 SSE, NC US', 73),
#  ('WATKINS GLEN 3.9 W, NY US', 72),
#  ('EVANSVILLE 0.4 E, WI US', 72),
#  ('SOUTHHAMPTON, NY US', 72),
#  ('TIPTONVILLE, TN US', 72),
#  ('CASPER 5.8 SW, WY US', 72),
#  ('HUNTINGTON BEACH 2.0 ESE, CA US', 72),
#  ('TORONTO SUNNYBROOK, CA', 72),
#  ('ROSEVILLE 0.8 SE, MN US', 72),
#  ('PORTOLA HILLS 1.7 WNW, CA US', 72),
#  ('WEYMOUTH 0.5 NW, MA US', 72),
#  ('TEXARKANA 10.8 E, AR US', 71),
#  ('MELROSE 1 NE, NY US', 71),
#  ('PUTNAM LAKE, CT US', 71),
#  ('PALI GOLF COURSE 788.1, HI US', 71),
#  ('CAMP BF 2 CCC CACHE, OK US', 71),
#  ('ROSWELL 4.1 NNE, NM US', 71),
#  ('VISTA 1.2SE, CA US', 71),
#  ('BLACKWATER MARYLAND, MD US', 71),
#  ('KING GEORGE 6.3 WNW, VA US', 71),
#  ('LULA, MS US', 70),
#  ('WESTPORT 2.5 ENE, CT US', 70),
#  ('SCOTTSBLUFF 1 E, NE US', 70),
#  ('BERLIN 0.7 SW, MD US', 70),
#  ('OLNEY 1.4 ENE, MD US', 70),
#  ('BIG SPRING 1.5 E, TX US', 70),
#  ('PHILIP S W GOLDSON INTERNATIONAL, BH', 70),
#  ('LEXINGTON FAYETTE 6.3 S, KY US', 69),
#  ('EDGARTOWN, MA US', 69),
#  ('MILL CREEK RANGER STATION, CA US', 69),
#  ('GRAND JUNCTION 2.3 N, CO US', 69),
#  ('DAGSBORO 7.1 ENE, DE US', 69),
#  ('DARIEN 0.4 SSE, IL US', 69),
#  ('EAST BETHEL 3.0 NE, MN US', 69),
#  ('OLNEY 1.5 NE, IL US', 69),
#  ('DANVILLE, KY US', 69),
#  ('THURMONT 0.8 SSE, MD US', 69),
#  ('PLEASANT HILL LAKE, OH US', 69),
#  ('NEW BLOOMFIELD, PA US', 69),
#  ('PEORIA 1, IL US', 68),
#  ('EDEN PRAIRIE 2.3 WNW, MN US', 68),
#  ('MARSHFIELD MUNICIPAL AIRPORT, MA US', 68),
#  ('BINGHAMTON 2.7 N, NY US', 68),
#  ('DECATUR 1.8 WSW, IL US', 68),
#  ('ANNAPOLIS POLICE BAR, MD US', 68),
#  ('DALLAS 2.7 WNW, TX US', 68),
#  ('RUSSELLS POINT LAKEV, OH US', 68),
#  ('MERRITT ISLAND, FL US', 68),
#  ('CENTRAL POINT, OR US', 68),
#  ('CHINCOTEAGUE 1.3 SSW, VA US', 68),
#  ('WESTBROOK CENTER 1.5 NE, CT US', 68),
#  ('BEAR RIVER REFUGE, UT US', 68),
#  ('FLAMINGO RANGER STATION, FL US', 68),
#  ('LYTLE CREEK FOOTHILL, CA US', 68),
#  ('SHREVEPORT DOWNTOWN AIRPORT, LA US', 68),
#  ('DENTON 2 E, MD US', 68),
#  ('NORTH HAMPTON, NH US', 68),
#  ('STONE RIDGE 0.7 N, NY US', 68),
#  ('ROCK HILL 3 SW, NY US', 68),
#  ('WYALUSING 2.8 SSW, PA US', 68),
#  ('CANFIELD 1 S, OH US', 67),
#  ('ODESSA, DE US', 67),
#  ('SOUTH GATE RIDGE 0.5 E, FL US', 67),
#  ('PORT ARANSAS 32 NNE, TX US', 67),
#  ('DALTON, GA US', 67),
#  ('FORT SMITH, AR US', 67),
#  ('DURANGO 6.7 SSE, CO US', 67),
#  ('SPARTA, CA', 67),
#  ('SACRAMENTO, CA US', 67),
#  ('MIFFLINBURG 2 NW, PA US', 67),
#  ('LAGUNA ATASCOSA TEXAS, TX US', 67),
#  ('GOAT ROCK, AL US', 67),
#  ('WELDON SPRING NWS, MO US', 67),
#  ('THUNDER BAY BURWOOD, CA', 67),
#  ('LONOKE 1.2 SSW, AR US', 67),
#  ('VANCE BRAND AIRPORT, CO US', 67),
#  ('NEWTON 6.5 WNW, KS US', 67),
#  ('TYLER 3.7 S, TX US', 67),
#  ('FORT EDMONTON, CA', 66),
#  ('LACKLAND AFB 3.5 SSE, TX US', 66),
#  ('LEAMINGTON 6.4 SE AGRIS, CA', 66),
#  ('ABERDEEN 1.1 NNW, FL US', 66),
#  ('LITTLE ROCK STATE CAPITOL, AR US', 66),
#  ('LYNXVILLE DAM 9, WI US', 66),
#  ('FAWNSKIN CALIFORNIA, CA US', 66),
#  ('SPRING VALLEY 1.7 N, NY US', 66),
#  ('MYAKKA RIVER STATE PARK, FL US', 66),
#  ('EAST MORICHES 0.6 WNW, NY US', 66),
#  ('HEMLOCK, NY US', 66),
#  ('FIRST CONNECTICUT LAKE, NH US', 66),
#  ('HORSEHEADS 2.7 SSE, NY US', 66),
#  ('MULLICA HILL 1.3 NNW, NJ US', 66),
#  ('WAUBAY NATIONAL WILD LIFE, SD US', 66),
#  ('ABSECON CITY 0.4 E, NJ US', 66),
#  ('FRANKLIN 2 SW, NJ US', 66),
#  ('MCALLEN MILLER INTERNATIONAL AIRPORT, TX US', 66),
#  ('HAMPTON 7.5 WNW, VA US', 66),
#  ('HANOVER 1.4 NNE, NH US', 65),
#  ('NANTUCKET 2.2 E, MA US', 65),
#  ('WILLIAMSPORT REGIONAL AIRPORT, PA US', 65),
#  ('MOSCOW 1.3 SW, ID US', 65),
#  ('AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US', 65),
#  ('CHAMBERSBURG 0.9 SE, PA US', 65),
#  ('PORT TOBACCO VILLAGE 1.0 S, MD US', 65),
#  ('ESTES PARK 0.7 W, CO US', 65),
#  ('BOSQUE DEL APACHE, NM US', 65),
#  ('BROUGHAM, CA', 65),
#  ('ROAN HIGH KNOB, NC US', 65),
#  ('SHENANDOAH JUNCTION 2.8 SE, WV US', 65),
#  ('CALDWELL 3 S, ID US', 65),
#  ('RINGWOOD, NJ US', 65),
#  ('LOCUST VALLEY 0.3 E, NY US', 65),
#  ('RAPID CITY 2.1 NW, SD US', 65),
#  ('CHIPPEWA FALLS 4.4 NE, WI US', 65),
#  ('PALO ALTO 0.8 NNE, CA US', 64),
#  ('SAVANNA TRI TOWNSHIP AIRPORT, IL US', 64),
#  ('MACON 1.7 WSW, GA US', 64),
#  ('CAPE CORAL 5.1 WSW, FL US', 64),
#  ('KENOSHA REGIONAL AIRPORT, WI US', 64),
#  ('SAINT CHARLES, AR US', 64),
#  ('FRENCHGLEN, OR US', 64),
#  ('DALLAS 0.5 E, PA US', 64),
#  ('SCOTTSVILLE 1.2 E, VA US', 64),
#  ('LOS OSOS 0.5 N, CA US', 64),
#  ('CHICAGO GRANT PARK, IL US', 64),
#  ('MADISON 2 SE, SD US', 64),
#  ('OKAY 3 W LOCK 17, OK US', 64),
#  ('CHESTER 6.6 E, VA US', 64),
#  ('DEEP RIVER 1.5 SE MNRF, CA', 64),
#  ('MARQUETTE 0.7 SSW, MI US', 64),
#  ('MAHOPAC 2.5 WSW, NY US', 64),
#  ('TIFFIN, OH US', 64),
#  ('LANGHORNE 0.5 E, PA US', 64),
#  ('VIRGINIA BEACH 6.8 NNW, VA US', 64),
#  ('ITHACA, NY US', 63),
#  ('RAY BROOK, NY US', 63),
#  ('ALBUQUERQUE 4.7 N, NM US', 63),
#  ('LA CROSSE, WI US', 63),
#  ('HAMILTON TWP 2.8 WSW, NJ US', 63),
#  ('DECORAH 7.9 ENE, IA US', 63),
#  ('MARYSVILLE 5.0 N, CA US', 63),
#  ('CALGARY 2.0 NW BRBC, CA', 63),
#  ('GAINESVILLE 5.0 SSW, FL US', 63),
#  ('SPRINGFIELD 0.7 ENE, MO US', 63),
#  ('LAS VEGAS EXPERIMENTAL PLOT, NM US', 63),
#  ('BURNETT 3 S, WI US', 63),
#  ('MONTE NIDO 0.2 SSW, CA US', 63),
#  ('SAN MATEO 3.4 SSW, CA US', 63),
#  ('HERRIN 3.4 S, IL US', 63),
#  ('MINETTO 0.1 SE, NY US', 63),
#  ('MIDLAND NUMBER 2, MI US', 63),
#  ('HELENA MONTANA, MT US', 63),
#  ('ESPANOLA 1.1 SE, NM US', 63),
#  ('CONCORD 2 SE, CA US', 63),
#  ('KEITHSBURG, IL US', 63),
#  ('LUDLOW 2.3 SW, MA US', 63),
#  ('GLENSHAW 1.3 NW, PA US', 62),
#  ('VANCOUVER MOUNT PLEASANT, CA', 62),
#  ('FARMINGTON 0.4 NNE, AR US', 62),
#  ('NORTHRIDGE CAL STATE, CA US', 62),
#  ('MULESHOE NWR, TX US', 62),
#  ('MEREDITH 7.3 S, NH US', 62),
#  ('BROOKINGS 8.0 SSW, SD US', 62),
#  ('ST. MICHAELS 0.7 SE, MD US', 62),
#  ('CLAUDE 17.3 SW, TX US', 62),
#  ('SAULT STE M FORESTRY, MI US', 62),
#  ('TAVERNIER, FL US', 62),
#  ('SHENANDOAH MUNICIPAL AIRPORT, IA US', 62),
#  ('STORRS, CT US', 62),
#  ('AFTON 1.6 E, MN US', 62),
#  ('CLINTON, NJ US', 62),
#  ('BRIDGEWATER 0.3 SE, VA US', 62),
#  ('WESTMINSTER 5.5 NW, VT US', 62),
#  ('SPARTANBURG, SC US', 61),
#  ('FOLKSTON 9 SW, GA US', 61),
#  ('WATERVILLE 2.5 NNE, ME US', 61),
#  ('TERRE HAUTE 4.0 S, IN US', 61),
#  ('COLUMBIA 4.4 SSW, MO US', 61),
#  ('SASKATOON 8.0 S, CA', 61),
#  ('RIVER EDGE 0.4 NNE, NJ US', 61),
#  ('BIG PINE KEY 1.5 SE, FL US', 61),
#  ('MOUNT PLEASANT, MI US', 61),
#  ('CROTON LAKE, NY US', 61),
#  ('CHINA LAKE NAF, CA US', 61),
#  ('RARITAN 0.3 NNE, NJ US', 61),
#  ('BURTON 1 W, OH US', 61),
#  ('WESTERVILLE 4.0 N, OH US', 61),
#  ('BAKER CITY AIRPORT, OR US', 61),
#  ('WELDER W LIFE FOUND, TX US', 61),
#  ('DOWAGIAC 2 E, MI US', 61),
#  ('FREEPORT 2 NW, TX US', 61),
#  ('FABIO BAUDRIT, CS', 61),
#  ('MAYNARD 2, MA US', 60),
#  ('POUGHKEEPSIE 4.7 ESE, NY US', 60),
#  ('WINNIPEG 5.3 SW, CA', 60),
#  ('NEW HOLLAND, NC US', 60),
#  ('SKYLAND, VA US', 60),
#  ('BLACKSBURG 0.4 N, VA US', 60),
#  ('COLUMBIA 8 N, SD US', 60),
#  ('SANTA FE 0.8 S, NM US', 60),
#  ('SPAVINAW, OK US', 60),
#  ('GRAND FORKS INTERNATIONAL AIRPORT, ND US', 60),
#  ('SAINT HELENA 6 NE, CA US', 60),
#  ('CHATHAM, NY US', 60),
#  ('VICTORIA 6.0 NNW, CA', 60),
#  ('PLANTATION 3.4 E, FL US', 60),
#  ('DELLWOOD 0.5 NNW, MN US', 60),
#  ('PLYMOUTH 1.6 WNW, OH US', 60),
#  ('RICES LANDING L 6, PA US', 60),
#  ('WILD ROSE 0.5 E, WI US', 60),
#  ('DURHAM 7.5 NNE, NC US', 59),
#  ('PROVIDENCE, RI US', 59),
#  ('CHICAGO BOTANIC GARDEN, IL US', 59),
#  ('FORT PIERCE ARC, FL US', 59),
#  ('LYNCHBURG 1.3 SSW, VA US', 59),
#  ('CEDAR FALLS 0.4 WNW, IA US', 59),
#  ('SALISBURY 5.5 SW, MD US', 59),
#  ('MOUND CITY 0.2 WNW, MO US', 59),
#  ('ALPINE 2 NE, IN US', 59),
#  ('POTOMAC 5.0 WNW, MD US', 59),
#  ('SULLIVAN 2.4 SSE, ME US', 59),
#  ('BELLPOINT, OH US', 59),
#  ('DARIEN 4.2 NNE, GA US', 59),
#  ('ROCK HALL, MD US', 59),
#  ('MAYS POINT LOCK 25, NY US', 59),
#  ('ELYRIA LORAIN CO AIRPORT, OH US', 59),
#  ('PALM CITY 3.1 NW, FL US', 59),
#  ('CEDARVILLE, NJ US', 59),
#  ('NEW BEDFORD COOP, MA US', 58),
#  ('FALLS VILLAGE, CT US', 58),
#  ('ST. DAVID, IL US', 58),
#  ('AUGUSTA DANIEL FIELD AIRPORT, GA US', 58),
#  ('EAST WENATCHEE 2.5 NNE, WA US', 58),
#  ('OREGON INLET, NC US', 58),
#  ('PETERBOROUGH 1.9 NNE, CA', 58),
#  ('WAUSAU RECORD HERALD, WI US', 58),
#  ('GUNNISON 3.2 N, CO US', 58),
#  ('PINE MOUNTAIN 2.8 SE, GA US', 58),
#  ('CHICO 1.8 SW, CA US', 58),
#  ('HEBRON 5.6 SW, IN US', 58),
#  ('HYDE PARK 0.7 NW, UT US', 58),
#  ('SHIOCTON, WI US', 58),
#  ('DELTA LADNER SOUTH, CA', 58),
#  ('NEW LEXINGTON 2 NW, OH US', 58),
#  ('RHINELANDER 0.6 SSW, WI US', 58),
#  ('STAFFORD KANSAS, KS US', 58),
#  ('ENNIS MONTANA, MT US', 58),
#  ('ERROL, NH US', 58),
#  ('TUCSON 9.4 NW, AZ US', 58),
#  ('WASHINGTON 7.6 SE, NC US', 58),
#  ('HUNTSVILLE, TX US', 58),
#  ('EDINBURG 17 NNE, TX US', 58),
#  ('CARLETON PLACE, CA', 58),
#  ('FERNDALE 2 NW, CA US', 58),
#  ('HULAH DAM, OK US', 58),
#  ('BLUE CANYON OREGON, OR US', 58),
#  ('STEVENS POINT 0.9 SSW, WI US', 58),
#  ('MATECANA, CO', 58),
#  ('MADISON 3.7 ENE, MS US', 57),
#  ('MECCA, OH US', 57),
#  ('CORVALLIS, OR US', 57),
#  ('BAY CITY 0.7 NNW, OR US', 57),
#  ('SALTON SEA NAAF, CA US', 57),
#  ('ANCHORAGE 4.7 SSW, AK US', 57),
#  ('LEXINGTON 0.9 NW, OH US', 57),
#  ('DEL RIO 7.8 NNW, TX US', 57),
#  ('ADA, MI US', 57),
#  ('OCONOMOWOC 1.2 NNE, WI US', 57),
#  ('SANTA CRUZ 3.1 NW, CA US', 57),
#  ('WACO 7.7 ESE, TX US', 57),
#  ('ZELLWOOD, FL US', 57),
#  ('WABASHA 0.9 NNE, MN US', 57),
#  ('TRAVERSE CITY, MI US', 57),
#  ('SANTA ROSA 0.4 NW, CA US', 57),
#  ('ATHENS 2.2 NNW, NY US', 57),
#  ('PLAINFIELD, VT US', 57),
#  ('PORT ROWAN 6.2 SW NSCIA, CA', 57),
#  ('BAINBRIDGE, GA US', 57),
#  ('ILLINOIS CITY DAM 16, IL US', 57),
#  ('STEVENSVILLE 1 SE, MI US', 57),
#  ('VERGENNES, VT US', 57),
#  ('NEW RICHMOND 3.1 S, WI US', 57),
#  ('TAUNTON MUNICIPAL AIRPORT, MA US', 56),
#  ('BRATTLEBORO 3.1 SW, VT US', 56),
#  ('FURLONG 0.7 SW, PA US', 56),
#  ('SAINT JAMES CITY 0.4 SSE, FL US', 56),
#  ('LEWISBURG 3 N, WV US', 56),
#  ('SALEM 2.2 WNW, OR US', 56),
#  ('AMES MUNICIPAL AIRPORT, IA US', 56),
#  ('WHEELING 4.9 NNE, WV US', 56),
#  ('LAS VEGAS 7.5 NW, NV US', 56),
#  ('ADAMS, MA US', 56),
#  ('OSHKOSH 2.0 W, WI US', 56),
#  ('REGINA 3.8 NW, CA', 56),
#  ('HIBBING POWER SUBSTN, MN US', 56),
#  ('SILVER CITY 3.4 S, NM US', 56),
#  ('NORTH HATLEY, CA', 56),
#  ('HILTON HEAD ISLAND 1.2 WNW, SC US', 56),
#  ('SANDIA PARK 0.5 S, NM US', 56),
#  ('PESHTIGO, WI US', 56),
#  ('CRYSTAL BEACH 3.7 ENE, TX US', 56),
#  ('ROBSTOWN 6.2 ENE, TX US', 56),
#  ('LESAGE GREENBOTTOM, WV US', 56),
#  ('CEDAR RAPIDS 2, IA US', 55),
#  ('LEWISTON 1 N, US', 55),
#  ('ATLANTA WEATHER BUREAU CITY, GA US', 55),
#  ('BARABOO RIVER, WI US', 55),
#  ('MANITOWOC 1.9 NNW, WI US', 55),
#  ('MARYVILLE 1.4 SSW, MO US', 55),
#  ('SAUK CITY 1.0 NW, WI US', 55),
#  ('NASHUA BOIRE FIELD, NH US', 55),
#  ('MORGANTOWN HART FIELD, WV US', 55),
#  ('COMOX 1.0 E, CA', 55),
#  ('KITCHENER CITY ENG 1, CA', 55),
#  ('HOFFMAN ESTATES 1.6 SE, IL US', 55),
#  ('ST INIGOES WEBSTER NAVAL OUTLYING FIELD, MD US', 55),
#  ('EAST LANSING 1.8 NNE, MI US', 55),
#  ('WAVERLY, IA US', 55),
#  ('SAN ANGELO 2.2 WSW, TX US', 55),
#  ('CUMBERLAND, MD US', 55),
#  ('CONCORD 1.6 SSE, NH US', 55),
#  ('EDMUNDS ARROWWOOD RE, ND US', 55),
#  ('MISSION 4 W, TX US', 55),
#  ('LITTLE SHEMOGUE, CA', 55),
#  ('NILES 2.7 W, MI US', 55),
#  ('WINONA, MN US', 55),
#  ('WRIGHT PATMAN DM AND LK, TX US', 55),
#  ('NAPANEE, CA', 55),
#  ('COAL CITY 0.4 N, IL US', 55),
#  ('NAPLES 1.3 SE, FL US', 55),
#  ('SYCAMORE 2.2 NNE, IL US', 55),
#  ('ST JOSEPH WEATHER BUREAU OFFICE CITY, MO US', 55),
#  ('WELLSVILLE 4 NNW, NY US', 55),
#  ('CORPUS CHRISTI 3.6 S, TX US', 55),
#  ('PORT HURON ST CLAIR CO INTERNATIONAL AIRPORT, MI US', 54),
#  ('MARSHALL, IN US', 54),
#  ('PARK FALLS DNR HQ, WI US', 54),
#  ('PORT HOPE, CA', 54),
#  ('SACKVILLE, CA', 54),
#  ('PEMBROKE 1.1 WSW, ME US', 54),
#  ('OYSTER 1 W, VA US', 54),
#  ('CARLSBAD CAVERNS, NM US', 54),
#  ('PUXICO 1 SE, MO US', 54),
#  ('ASHWOOD, TN US', 54),
#  ('ZION NATIONAL PARK, UT US', 54),
#  ('HAVRE DE GRACE 4.0 WNW, MD US', 54),
#  ('MONTROSE 6.0 E, MO US', 54),
#  ('MILTON, DE US', 54),
#  ('PANAMA CITY, FL US', 54),
#  ('HOLLAND 4.2 NNE, MI US', 54),
#  ('GUILFORD 0.9 NW, NY US', 53),
#  ('GUELPH OAC, CA', 53),
#  ('WHISPERING PINES 1.6 ESE, NC US', 53),
#  ('BELLINGHAM 4.6 NNW, WA US', 53),
#  ('PAINESVILLE HIGHWAY DE, OH US', 53),
#  ('PRESQUE ISLE 1.3 WSW, ME US', 53),
#  ('POCATELLO 2.9 E, ID US', 53),
#  ('EMORY, VA US', 53),
#  ('BRANDENBURG, KY US', 53),
#  ('CHISOS BASIN TEXAS, TX US', 53),
#  ('MOROCCO, IN US', 53),
#  ('REXBURG, ID US', 53),
#  ('NATCHEZ, MS US', 53),
#  ('GONZALES 6.7 NNW, TX US', 53),
#  ('NORTH EAST 3.8 SE, MD US', 53),
#  ('DRYDEN, CA', 53),
#  ('CELINA 3 NE, OH US', 53),
#  ('JACKSON HOLE AIRPORT, WY US', 53),
#  ('TERRACE A, CA', 53),
#  ('STEVI MONTANA, MT US', 53),
#  ('HAMMON 0.2 ESE, OK US', 53),
#  ('WASHBURN 5.1 WNW, WI US', 53),
#  ('BLACK RIVER FALLS AREA AIRPORT, WI US', 53),
#  ('SHAWANO MUNICIPAL AIRPORT, WI US', 53),
#  ('COLLEGE 3 NNW, AK US', 53),
#  ('RENO 4.5 S, NV US', 53),
#  ('LA RUE, OH US', 53),
#  ('OAKVILLE TWN, CA', 53),
#  ('PINE BLUFF, AR US', 53),
#  ('NEWPORT 2.4 WNW, DE US', 53),
#  ('AUBURNDALE 3.0 SSW, FL US', 53),
#  ('GHENT 2.8 ENE, MN US', 53),
#  ('SLIPPERY ROCK 1.7 SSE, PA US', 53),
#  ('HAMBURG 2, PA US', 53),
#  ('PLANO 6.2 W, TX US', 53),
#  ('MONT BELVIEU 1.5 NNW, TX US', 53),
#  ('DUBOIS, WY US', 53),
#  ('CANTIL, CA US', 53),
#  ('PLYMOUTH, VT US', 52),
#  ('FLAGSTAFF 4.1 NE, AZ US', 52),
#  ('WINTERPORT 2.9 N, ME US', 52),
#  ('ERIE 5.7 SSE, PA US', 52),
#  ('KLAMATH FALLS AG STATION, OR US', 52),
#  ('TITUSVILLE NASA SHUTTLE LANDING FACILITY, FL US', 52),
#  ('GREENFIELD, MA US', 52),
#  ('HOT SPRINGS, TX US', 52),
#  ('KENNEWICK 0.4 NNE, WA US', 52),
#  ('EAGAN 2.4 WSW, MN US', 52),
#  ('WESTOVER 2.6 WNW, MD US', 52),
#  ('YORK BEACH 0.6 ESE, ME US', 52),
#  ('GEORGEVILLE, CA', 52),
#  ('PATAGONIA PATON CENTER, AZ US', 52),
#  ('SATURNA CAPMON, CA', 52),
#  ('HICKMAN 1 E, KY US', 52),
#  ('BURLINGTON 2.1 N, IA US', 52),
#  ('ALPENA WASTEWATER PLANT, MI US', 52),
#  ('WEYAUWEGA 0.1 S, WI US', 52),
#  ('CAMBRIA, WI US', 52),
#  ('ST JOHN S, CA', 52),
#  ('POINT REYES STATION, CA US', 52),
#  ('HOTCHKISS 3.7 WSW, CO US', 52),
#  ('KISSIMMEE 2, FL US', 52),
#  ('MICCO 1.3 NW, FL US', 52),
#  ('HAMMOND 3.0 SW, IN US', 52),
#  ('CHICAGO SPRINGFIELD PUMP, IL US', 52),
#  ('ARNETT 8 WSW MESONET, OK US', 52),
#  ('TITUSVILLE 2 S, PA US', 52),
#  ('QUINCY MEMORIAL BRID, IL US', 51),
#  ('PUEBLO 7.0 ESE, CO US', 51),
#  ('CANTON REPOSITORY, OH US', 51),
#  ('CARROLLWOOD 2.0 SSE, FL US', 51),
#  ('BOWIE 2.8 WNW, MD US', 51),
#  ('HUNTINGTON 1.0 S, WV US', 51),
#  ('BLUFF LAKE, MS US', 51),
#  ('AZTEC 4.1 WSW, NM US', 51),
#  ('LODI 1.0 NNW, CA US', 51),
#  ('KEENWILD CALIFORNIA, CA US', 51),
#  ('CROZET 2 N, VA US', 51),
#  ('KENOGAMI, CA', 51),
#  ('UMBARGER, TX US', 51),
#  ('LOVING, NM US', 51),
#  ('BALMORHEA, TX US', 51),
#  ('THEDFORD, CA', 51),
#  ('TWENTYNINE PALMS 1.5 SW, CA US', 51),
#  ('BOISE 1.5 NE, ID US', 51),
#  ('LAFAYETTE, LA US', 51),
#  ('PETOSKEY, MI US', 51),
#  ('WEST SAND LAKE 2 S, NY US', 51),
#  ('BEACH CITY LAKE, OH US', 51),
#  ('BODEGA BAY 4.8 NNW, CA US', 51),
#  ('EASTPORT 1.5 SE, ME US', 51),
#  ('GRENADA DAM, MS US', 51),
#  ('BLAIRSTOWN TWP 1.8 W, NJ US', 51),
#  ('HENDERSON 4.7 NE, NV US', 51),
#  ('OAKFIELD 6.5 WNW, NY US', 51),
#  ('NEAPOLIS EXPERIMENT FARM, OH US', 51),
#  ('LOCK HAVEN, PA US', 51),
#  ('LITTLE COMPTON 1.7 NW, RI US', 51),
#  ('PALESTINE 6 WNW, TX US', 51),
#  ('SOUTH LONDONDERRY, VT US', 51),
#  ('BENZONIA, MI US', 50),
#  ('GIBBSVILLE, WI US', 50),
#  ('IGOR I SIKORSKY MEMORI AIRPORT, CT US', 50),
#  ('OWEN SOUND 1.4 SSW GSCA, CA', 50),
#  ('OSHAWA WPCP, CA', 50),
#  ('FORT ATKINSON, WI US', 50),
#  ('BARRIE LANDFILL, CA', 50),
#  ('EMPORIA 5.6 ESE, KS US', 50),
#  ('PIERRE 1.6 WSW, SD US', 50),
#  ('PRESCOTT 0.8 WSW, AZ US', 50),
#  ('LOS BANOS, CA US', 50),
#  ('KINGSBURY 0.3 WNW, IN US', 50),
#  ('RESERVE 0.8 E, LA US', 50),
#  ('NACOGDOCHES ARBOR OAK, TX US', 50),
#  ('WILCOX LAKE, CA', 50),
#  ('HOMER AIRPORT, AK US', 50),
#  ('ONEIDA 0.7 NNE, NY US', 50),
#  ('KENTON 6.1 E, OK US', 50),
#  ('ST. GEORGE 4.1 NNW, UT US', 50),
#  ('BAILEYS HARBOR 2.3 WNW, WI US', 50),
#  ('NATCHITOCHES NUMBER 2, LA US', 50),
#  ('OWEGO 1.3 NW, NY US', 50),
#  ('WOODFORDS, CA US', 50),
#  ('MOUNT CALVARY 1.6 WSW, WI US', 50),
#  ('NUNN 7 NNE, CO US', 50),
#  ('SCHENLEY LOCK 5, PA US', 50),
#  ('ALVARADO, CA US', 50),
#  ('ATHOL, MA US', 50),
#  ('FERGUS FALLS 0.5 E, MN US', 50),
#  ('ATSION, NJ US', 50),
#  ('WELLSBORO 2 E, PA US', 50),
#  ('FALCON LAKE TEXAS, TX US', 50),
#  ('WAYNESBORO 1.5 WSW, VA US', 50),
#  ('GREENWOOD A, CA', 50),
#  ('GORE BAY CLIMATE, CA', 50),
#  ('ARKADELPHIA, AR US', 50),
#  ('CONWAY 0.8 S, AR US', 50),
#  ('FRANKFORT 1.9 N, KY US', 50),
#  ('ORONO, ME US', 50),
#  ('CAMBRIDGE, MA US', 49),
#  ('PHILADELPHIA FRANKLIN INSTITUTE, PA US', 49),
#  ('PROVO BYU, UT US', 49),
#  ('OLYMPIA PRIEST PT PA, WA US', 49),
#  ('JAMESTOWN STATE HOSPITAL, ND US', 49),
#  ('FLORENCE REGIONAL AIRPORT, SC US', 49),
#  ('OCEAN PARK 2.2 N, WA US', 49),
#  ('DECATUR 4 SE, AL US', 49),
#  ('WEST WEBER 1.0 ESE, UT US', 49),
#  ('ST. AUGUSTINE 3.4 NW, FL US', 49),
#  ('MONTE VISTA 7.0 SE, CO US', 49),
#  ('ARLINGTON, WI US', 49),
#  ('ROCHESTER 4.1 N, MN US', 49),
#  ('MONROE 3.0 S, MI US', 49),
#  ('ATIKOKAN, CA', 49),
#  ('RIVERTON, MN US', 49),
#  ('MINDEN, CA', 49),
#  ('DURAND 0.5 SW, WI US', 49),
#  ('SHELDON, WI US', 49),
#  ('EVERGREEN 5.0 NW, CO US', 49),
#  ('BABSON PARK 1 ENE, FL US', 49),
#  ('CAMANCHE 1.2 W, IA US', 49),
#  ('WESTVILLE 0.6 SSW, IL US', 49),
#  ('UTICA STARVED ROCK D, IL US', 49),
#  ('OWENTON 1, KY US', 49),
#  ('CHELSEA 2.4 WNW, MI US', 49),
#  ('LAURELVILLE, OH US', 49),
#  ('TYRONE, PA US', 49),
#  ('HERMITAGE 0.9 WSW, TN US', 49),
#  ('HUDGINS 1.7 ESE, VA ', 49),
#  ('SHERIDAN 1.7 NW, WY US', 49),
#  ('ST PIERRE, FR', 49),
#  ('PLYMOUTH 6.6 SE, MA US', 48),
#  ('LEOMINSTER 1.5 S, MA US', 48),
#  ('LEXINGTON 5.3 W, VA US', 48),
#  ('LIBBY, MT US', 48),
#  ('EVANSVILLE MUSEUM, IN US', 48),
#  ('NEW CASTLE 0.1 NNE, IN US', 48),
#  ('FORT PATRICK HENRY D, TN US', 48),
#  ('HENNEPIN POWER PLANT, IL US', 48),
#  ('FOXHOLM 7 N, ND US', 48),
#  ('BEND 0.8 ESE, OR US', 48),
#  ('FRANCONIA 0.8 NE, NH US', 48),
#  ('PLATTSBURGH AFB, NY US', 48),
#  ('GRANTSBURG, WI US', 48),
#  ('DUNDAS 3.2 SSW, MN US', 48),
#  ('LOUISBOURG, CA', 48),
#  ('ROUND HILL 2.7 WSW, VA US', 48),
#  ('BRIGHTON, CA', 48),
#  ('CHILLICOTHE, IL US', 48),
#  ('BAYBORO 4.4 ENE, NC US', 48),
#  ('WINFIELD 2.1 SSW, KS US', 48),
#  ('INDIANAPOLIS 12.6 NW, IN US', 48),
#  ('MIAMI 5.7 N, FL US', 48),
#  ('DALLAS 1.3 WSW, OR US', 48),
#  ('SLANESVILLE 2.1 SE, WV US', 48),
#  ('JEKYLL ISLAND 0.6 E, GA US', 48),
#  ('AUGUSTA, ME US', 48),
#  ('BIDDEFORD, ME US', 48),
#  ('BINGHAM LAKE, MN US', 48),
#  ('LIVINGSTON 6.6 ESE, MT US', 48),
#  ('OTTAWA NWR, OH US', 48),
#  ('MOXEE, WA US', 48),
#  ('BELLEVUE OFFUTT AFB, NE US', 47),
#  ('DAYTONA BEACH, FL US', 47),
#  ('SOUTHAMPTON TWP 2.4 NW, NJ US', 47),
#  ('BEVERLY SHORES 0.4 NNE, IN US', 47),
#  ('MINOT, ND US', 47),
#  ('GREELEY 3.5 ESE, CO US', 47),
#  ('ROUND POND 0.7 SSW, ME US', 47),
#  ('GEORGETOWN 1.3 ENE, MA US', 47),
#  ('IMPERIAL DAM, CA US', 47),
#  ('GREENSBORO 4.1 NE, NC US', 47),
#  ('ALBERT LEA 1.6 SW, MN US', 47),
#  ('HARTFORD 0.9 SSE, WI US', 47),
#  ('ELBERT 8 SW, CO US', 47),
#  ('NEWALD 4 N, WI US', 47),
#  ('ST CHARLES CO AIRPORT, MO US', 47),
#  ('BRISTOL, VA US', 47),
#  ('ASHLAND 0.5 WNW, WI US', 47),
#  ('LINDEN 5.8 ENE, CA US', 47),
#  ('CALDER, ID US', 47),
#  ('LAKE MC MILLAN, NM US', 47),
#  ('CHATHAM 2 NE, MS US', 47),
#  ('RICHLAND CENTER, WI US', 47),
#  ('STANDISH 1 E, CA US', 47),
#  ('NEW PORT RICHEY 2.0 ENE, FL US', 47),
#  ('LYND NUMBER 1, MN US', 47),
#  ('PENTZ, CA', 47),
#  ('VERNON BRIDGE', 47),
#  ('PORTAL, AZ US', 47),
#  ('LAKE SOLANO, CA US', 47),
#  ('DURHAM 1.2 W, CT US', 47),
#  ('LAGRANGE 7.2 ESE, IN US', 47),
#  ('FUNKSTOWN 2.3 SW, MD US', 47),
#  ('THOMASTON, ME US', 47),
#  ('WABASHA, MN US', 47),
#  ('BAY SHORE 0.5 ESE, NY US', 47),
#  ('MILLVILLE 2 SW, PA US', 47),
#  ('PAWLEYS ISLAND 5.6 NNE, SC US', 47),
#  ('CLARKSVILLE 3.4 SSW, TN US', 47),
#  ('BURGETTSTOWN 2 W, PA US', 46),
#  ('TULSA INTERNATIONAL AIRPORT, OK US', 46),
#  ('BUCK FOREST, NC US', 46),
#  ('ACCOKEEK 0.5 N, MD US', 46),
#  ('ROME, GA US', 46),
#  ('LANDER AIRPORT, WY US', 46),
#  ('CEDAR KEY 1 WSW, FL US', 46),
#  ('BURNET 1.9 W, TX US', 46),
#  ('MERRILL MUNICIPAL AIRPORT, WI US', 46),
#  ('ANTHRACITE, CA', 46),
#  ('WATSONVILLE WATERWORKS, CA US', 46),
#  ('FREDONIA 0.8 WNW, NY US', 46),
#  ('KANAB, UT US', 46),
#  ('ALLEGANY, NY US', 46),
#  ('WASAGAMING, CA', 46),
#  ('MARGAREE FORKS, CA', 46),
#  ('CHANDLERVILLE RIVER, IL US', 46),
#  ('CHILTON 0.6 NNW, WI US', 46),
#  ('SURREY SUNNYSIDE, CA', 46),
#  ('HARRINGTON CDA CS, CA', 46),
#  ('SAN GREGORIO 2 SE, CA US', 46),
#  ('JONESBORO 0.3 NNE, IL US', 46),
#  ('OXFORD, MI US', 46),
#  ('HURON 2.5 SSW, OH US', 46),
#  ('HIGH KNOB, VA US', 46),
#  ('NANAIMO CHUB, CA', 46),
#  ('SCOTCH CREEK, CA', 46),
#  ('LAJAS SUBSTATION, US', 46),
#  ('BENICIA 1.0 N, CA US', 46),
#  ('CLAREMONT CALIFORNIA, CA US', 46),
#  ('WEED 5.4 N, CA US', 46),
#  ('WOODBURY 3 W, CT US', 46),
#  ('ATHENS 3.6 SSE, GA US', 46),
#  ('SALMON 0.2 NNW, ID US', 46),
#  ('PARK FOREST 1.0 SW, IL US', 46),
#  ('OAKLAND CITY 0.4 E, IN US', 46),
#  ('NORTH FALMOUTH 0.5 ENE, MA US', 46),
#  ('COLOMA 3 NNW, MI US', 46),
#  ('PRATT, MN US', 46),
#  ('SKANEATELES, NY US', 46),
#  ('YOUNGSTOWN 2.8 S, OH US', 46),
#  ('LAWRENCEBURG 7.0 NW, TN US', 46),
#  ('VERONA, VA US', 46),
#  ('UNIVERSITY PLACE 1.5 ESE, WA US', 46),
#  ('BLANCHARDVILLE NUMBER 2, WI US', 46),
#  ('BLUESTONE LAKE, WV US', 46),
#  ('FARMINGTON, ME US', 45),
#  ('GREENVILLE HIGHWAY DEP, OH US', 45),
#  ('SEYMOUR HIGHWAY GARAGE, IN US', 45),
#  ('GREAT FALLS 2.4 SW, MT US', 45),
#  ('SANDY HOOK, NJ US', 45),
#  ('WASHINGTON DAM 19, OH US', 45),
#  ('GARDINER, MT US', 45),
#  ('MECCA FIRE STATION, CA US', 45),
#  ('NORRIS DAM, TN US', 45),
#  ('ABERDEEN 1.5 SW, SD US', 45),
#  ('POCATELLO 9.0 WNW, ID US', 45),
#  ('OLIVE BRANCH, IL US', 45),
#  ('CLEMSON COLLEGE DARY, SC US', 45),
#  ('SALMON CREEK BEACH', 45),
#  ('ORCA, AK US', 45),
#  ('FRITCH 5.1 E, TX US', 45),
#  ('WESTCLIFFE, CO US', 45),
#  ('TAZEWELL, VA US', 45),
#  ('PITT MEADOWS ALOUETTE RIVER, CA', 45),
#  ('TORRANCE 2.8 SW, CA US', 45),
#  ('MOREHEAD CITY 1.2 NNE, NC US', 45),
#  ('CYPRUS LAKE CS, CA', 45),
#  ('COCO SOLO', 45),
#  ('FORT SHERMAN, PM', 45),
#  ('BALBOA ALBROOK, PM', 45),
#  ('KODIAK AIRPORT, AK US', 45),
#  ('EUFAULA WILDLIFE REF, AL US', 45),
#  ('GULF SHORES JACK EDWARDS AIRPORT, AL US', 45),
#  ('COLUSA 2 SSW, CA US', 45),
#  ('NEWBURY PARK 4 SW, CA US', 45),
#  ('ENGLEWOOD 3.7 NNW, FL US', 45),
#  ('NEWTON 8 W, GA US', 45),
#  ('KENNESAW 5.6 SW, GA US', 45),
#  ('JOLIET 0.4 S, IL US', 45),
#  ('PHIPPSBURG 4.8 S, ME US', 45),
#  ('ROSCOMMON 4.7 SW, MI US', 45),
#  ('CROOKSTON 0.6 ENE, MN US', 45),
#  ('HATTIESBURG 1.2 WSW, MS US', 45),
#  ('OCEAN SPRINGS 3.3 E, MS US', 45),
#  ('EDWARD MACDOWELL LAKE, NH US', 45),
#  ('SOUTH BEACH 2.7 SW, OR US', 45),
#  ('CRAWFORD 7.5 ENE, TX US', 45),
#  ('CHEYENNE 1.5 W, WY US', 45),
#  ('STORY 2.1 W, WY US', 45),
#  ('VERNON, CA', 44),
#  ('LEWISTON, ME US', 44),
#  ('YARMOUTH RCS, CA', 44),
#  ('BUSTLETON, PA US', 44),
#  ('GARDERE 1.2 ENE, LA US', 44),
#  ('ST PAUL 5 S, SC US', 44),
#  ('VAN WERT 1 S, OH US', 44),
#  ('PICKSTOWN, SD US', 44),
#  ('BEAR VALLEY, AZ US', 44),
#  ('DODGE CITY 1.4 NNE, KS US', 44),
#  ('LIBERTY 3 SSE, IN US', 44),
#  ('DUNCAN EAST, CA', 44),
#  ('CARRIZO CALIFORNIA, CA US', 44),
#  ('MEAFORD, CA', 44),
#  ('WIARTON, CA', 44),
#  ('KALIHIWAI RESERVOIR, HI US', 44),
#  ('WELDON 2, NC US', 44),
#  ('RACINE 3.0 WNW, WI US', 44),
#  ('SEDONA 9.0 WSW, AZ US', 44),
#  ('DEATH VALLEY, CA US', 44),
#  ('MILLIS 1.4 ENE, MA US', 44),
#  ('SWANNANOA 0.4 NNE, NC US', 44),
#  ('LONE TREE, WA US', 44),
#  ('NAPPAN CDA, CA', 44),
#  ('ELIZABETHTOWN, NY US', 44),
#  ('WICHITA VALLEY FARM NUMBER 45, TX US', 44),
#  ('DOG POUND, CA', 44),
#  ('OKANAGAN FALLS 2 S, CA', 44),
#  ('SANDFIELD, CA', 44),
#  ('WELLESLEY ISLAND, NY US', 44),
#  ('ST LAZARE, CA', 44),
#  ('ELK 1.8 NNE, CA US', 44),
#  ('TROY 2.0 WNW, IL US', 44),
#  ('BEAVER FIRE TOWER, LA US', 44),
#  ('ALLEGAN 1, MI US', 44),
#  ('BEAVER MEADOW, NY US', 44),
#  ('WHITESBORO 2.3 SW, NY US', 44),
#  ('CHERRY FORK, OH US', 44),
#  ('COLLINSVILLE 3.2 S, OK US', 44),
#  ('WASHINGTON 3 NE, PA US', 44),
#  ('NORTHINGTON RANCH, TX US', 44),
#  ('KINGSVILLE 3.0 S, TX US', 44),
#  ('MIDLAND 5.8 SSE, TX US', 44),
#  ('LEXINGTON, VA US', 44),
#  ('WEST RUTLAND 1.2 N, VT US', 44),
#  ('ISLAND POND, VT US', 44),
#  ('PLYMOUTH, WI US', 44),
#  ('KILLALOE, CA', 44),
#  ('CHAMPAIGN 1.7 WSW, IL US', 43),
#  ('SOUTH PORTLAND 1.7 S, ME US', 43),
#  ('HARBERT, MI US', 43),
#  ('BEAVER CREEK, AZ US', 43),
#  ('KINGSTON BEVERLEY ST, CA', 43),
#  ('FOUNTAIN GROVE WILDLIFE REFUGE, MO US', 43),
#  ('MUIR WOODS, CA US', 43),
#  ('BANCROFT, CA', 43),
#  ('NEW CONCORD 4 NW, KY US', 43),
#  ('SPEARFISH 3.4 NNW, SD US', 43),
#  ('WINCHESTER, OR US', 43),
#  ('CRESCENT CITY 7.8 NNE, CA US', 43),
#  ('PLATTEVILLE MUNICIPAL AIRPORT, WI US', 43),
#  ('TUCSON 17 NW, AZ US', 43),
#  ('TEWAUKON NORTH DAKOTA, ND US', 43),
#  ('STURGEON BAY EXPERIMENTAL FARM, WI US', 43),
#  ('OROVILLE, CA US', 43),
#  ('DODGEVILLE WISCONSIN, WI US', 43),
#  ('WOODY POINT, CA', 43),
#  ('TRIMBLE 0.8 W, MO US', 43),
#  ('KULANI CONE 81, HI US', 43),
#  ('GREEN RIVER, WY US', 43),
#  ('WILLOW CREEK 1 NW, CA US', 43),
#  ('WEST GLACIER MONTANA, MT US', 43),
#  ('HAGERMAN 2 SW, ID US', 43),
#  ('WENTWORTH, NH US', 43),
#  ('CATONSVILLE 0.9 ENE, MD US', 43),
#  ('RECTOR 3 SSW, PA US', 43),
#  ('BERMUDA', 43),
#  ('BEAVERTON, CA', 43),
#  ('KONOCTI CALIFORNIA, CA US', 43),
#  ('REDDING 2.8 NW, CA US', 43),
#  ('PUEBLO WEST 4.7 SW, CO US', 43),
#  ('EAST HAMPTON 0.6 NE, CT US', 43),
#  ('DELAND MUNICIPAL AIRPORT SYDNEY H TAYLOR FIELD, FL US', 43),
#  ('CIMARRON KANSAS, KS US', 43),
#  ('HOWELL 2.2 ENE, MI US', 43),
#  ('GIBRALTAR 0.8 SW, MI US', 43),
#  ('WASHINGTON, MI US', 43),
#  ('AUSTIN WASTE WATER TREATMENT FACILITY, MN US', 43),
#  ('SARDIS DAM, MS US', 43),
#  ('FORT PECK, MT US', 43),
#  ('LAS CRUCES 3.1 SE, NM US', 43),
#  ('MOSQUITO CREEK LAKE, OH US', 43),
#  ('TISHOMINGO NATIONAL WR, OK US', 43),
#  ('GATLINBURG 2 SW, TN US', 43),
#  ('EAGLE LAKE RES CTR, TX US', 43),
#  ('FINCASTLE 1.9 NNW, VA US', 43),
#  ('MIDDLETOWN 0.1 SE, VA US', 43),
#  ('MOUNT HOREB 1 WSW, WI US', 43),
#  ('DEARBORN NUMBER 2, MI US', 42),
#  ('KEOKUK MUNICIPAL AIRPORT, IA US', 42),
#  ('WILLIAMSBURG 0.9 NNW, VA US', 42),
#  ('SAGINAW 3.0 NW, MI US', 42),
#  ('WALKER, MN US', 42),
#  ('GALENA, IL US', 42),
#  ('GLACIER BAY, AK US', 42),
#  ('FREEPORT 0.9 ESE, IL US', 42),
#  ('PENTICTON 3.4 NNE, CA', 42),
#  ('SITKA AIRPORT, AK US', 42),
#  ('MEDORA, ND US', 42),
#  ('TRACYTON 2.2 NE, WA US', 42),
#  ('LARAMIE 0.7 SW, WY US', 42),
#  ('DELTA WATERFOWL RANGER STATION, CA', 42),
#  ('TIBER DAM, MT US', 42),
#  ('MCCLELLANVILLE 0.2 ESE, SC US', 42),
#  ('CHESLEY, CA', 42),
#  ('BIGGAR, CA', 42),
#  ('WALLER BWI, TD', 42),
#  ('GUNTERSVILLE, AL US', 42),
#  ('CHESTER, CA US', 42),
#  ('GOULD 0.5 W, CO US', 42),
#  ('BATAVIA 0.3 N, IL US', 42),
#  ('HARDIN RIDGE INDIANA, IN US', 42),
#  ('MOUNT CARMEL 2, IL US', 42),
#  ('CHASSELL 4.0 N, MI US', 42),
#  ('CENTER CITY 0.8 WSW, MN US', 42),
#  ('WAVELAND 1.1 NW, MS US', 42),
#  ('WHITE OAK EAST 0.9 E, OH US', 42),
#  ('LA GRANDE MUNICIPAL AIRPORT, OR US', 42),
#  ('QUARRYVILLE 2.8 S, PA US', 42),
#  ('ONLEY 0.6 SE, VA US', 42),
#  ('PALMAR SUR, CS', 42),
#  ('YORK 4.2 NE, PA US', 41),
#  ('COEYMANS HOLLOW 2.1 N, NY US', 41),
#  ('JULIETTE, GA US', 41),
#  ('WALLACETOWN 1.9 S AGRIS, CA', 41),
#  ('MOUNT VERNON, IN US', 41),
#  ('TOWN BLUFF DAM, TX US', 41),
#  ('MARTINSVILLE, IL US', 41),
#  ('CHIPITA PARK 0.1 SE, CO US', 41),
#  ('LUDINGTON AIRPORT, MI US', 41),
#  ('PAUL 1 ENE, ID US', 41),
#  ('SCAPPOOSE INDUSTRIAL AIRPORT, OR US', 41),
#  ('WEST BEND 7.3 E, WI US', 41),
#  ('ROGERS CITY 5 W, MI US', 41),
#  ('VALLEY FALLS, OR US', 41),
#  ('AVINGER 6.6 S, TX US', 41),
#  ('MUD BAY, CA', 41),
#  ('GRANBY, CA', 41),
#  ('TUSCALOOSA 1.3 ENE, AL US', 41),
#  ('NORCO 2.3 SE, CA US', 41),
#  ...]

# %%
# !head stations_all.csv
# Out:
# elevation|mindate|maxdate|latitude|name|datacoverage|id|elevationUnit|longitude
# 139|1948-01-01|2014-01-01|31.5702|ABBEVILLE, AL US|0.8813|COOP:010008|METERS|-85.2482
# 249.3|1938-01-01|2015-11-01|34.2553|ADDISON, AL US|0.5059|COOP:010063|METERS|-87.1814
# 302.1|1940-05-01|1962-03-01|34.41667|ADDISON CENTRAL TOWER, AL US|0.9658|COOP:010071|METERS|-87.31667
# 172.2|1995-04-01|2015-11-01|33.17833|ALABASTER SHELBY CO AIRPORT, AL US|0.8064|COOP:010116|METERS|-86.78167
# 183.8|1949-01-01|1949-12-01|34.6891|BELLE MINA, AL US|1|COOP:010117|METERS|-86.8819
# 34.1|1935-05-01|1936-11-01|31.13333|ALAGA, AL US|0.2624|COOP:010125|METERS|-85.06667
# 53.3|1940-11-01|2014-12-01|32.2322|ALBERTA, AL US|0.9888|COOP:010140|METERS|-87.4104
# 348.1|1931-01-01|1977-06-01|34.23333|ALBERTVILLE, AL US|0.9535|COOP:010148|METERS|-86.16667
# 195.1|1969-10-01|2015-11-01|32.9452|ALEXANDER CITY, AL US|0.9946|COOP:010160|METERS|-85.948

# %%
mapper__name_to_id = {}
mapper__id_to_name = {}
mapper__id_to_activeyears = {}

with open("stations_all.csv") as csvfile:
    reader = csv.DictReader(csvfile, delimiter="|")
    for row in reader:
        mapper__name_to_id[row["name"]]=row["id"]
        mapper__id_to_name[row["id"]] = row["name"]
        year_start = row["mindate"][:4]
        year_end = row["maxdate"][:4]
        
        mapper__id_to_activeyears[row["id"]] = (year_start, year_end)

# %%
station_types = {}

for stn_name in unique_closest_station:
    if stn_name not in mapper__name_to_id:
        print(f"WARN: {stn_name} not found on current NOAA Stations Listing")
    else:
        stn_id = mapper__name_to_id[stn_name]
        print(f"{stn_name}: \t {stn_id}")
        station_type = stn_id.split(":")[0]
        station_types[station_type] = station_types.get(station_type, 0) + 1
# Out:
# TAUNTON MUNICIPAL AIRPORT, MA US: 	 WBAN:54777
# CAMBRIDGE, MA US: 	 GHCND:USC00191097
# SETAUKET EAST SETAUKET 0.3 SSE, NY US: 	 GHCND:US1NYSF0076
# DEVAULT 1 W, PA US: 	 GHCND:USC00362116
# MOLINE 1.0 WNW, IL US: 	 GHCND:US1ILRI0018
# WEST CHESTER 2 NW, PA US: 	 GHCND:USC00369464
# GREENPORT POWER HOUS, NY US: 	 GHCND:USC00303464
# WYNCOTE 0.3 ENE, PA US: 	 GHCND:US1PAMT0089
# CAMBRIDGE B, MA US: 	 GHCND:USC00191099
# WERNERSVILLE 0.5 ESE, PA US: 	 GHCND:US1PABR0009
# NEW YORK BENSONHURST, NY US: 	 GHCND:USC00305798
# OBERLIN, OH US: 	 GHCND:USC00336196
# MILFORD 5 NW, IL US: 	 GHCND:USC00115646
# NEEDHAM 1.2 E, MA US: 	 GHCND:US1MANF0017
# LANCASTER 5.8 WNW, PA US: 	 GHCND:US1PALN0007
# JAMAICA PLAIN, MA US: 	 GHCND:USC00193890
# ITHACA, NY US: 	 COOP:304178
# DELAWARE 3.7 NNW, OH US: 	 GHCND:US1OHDL0003
# DIXON 1.5 SW, IL US: 	 GHCND:US1ILLE0017
# NAHANT, MA : 	 GHCND:USC00195145
# PHILADELPHIA FRANKLIN INSTITUTE, PA US: 	 GHCND:USC00366886
# LEXINGTON FAYETTE 6.3 S, KY US: 	 GHCND:US1KYFY0002
# HILTON, NY US: 	 GHCND:USC00303881
# CHIPPEWA LAKE, OH US: 	 GHCND:USC00331541
# GLENVIEW 0.9 SW, IL US: 	 GHCND:US1ILCK0215
# LANSDOWNE 0.2 NNW, PA US: 	 GHCND:US1PADL0013
# CENTERVILLE 0.3 N, IN US: 	 GHCND:US1INWN0004
# CANANDAIGUA 2.6 SSW, NY US: 	 GHCND:US1NYON0007
# CADIZ 2, OH US: 	 GHCND:USC00331162
# CHICAGO 4.8 NNW, IL US: 	 GHCND:US1ILCK0179
# GREENVILLE 0.6 S, IN US: 	 GHCND:US1INFD0009
# AUBURN, NY US: 	 GHCND:USC00300321
# ROCHESTER 3.4 NNW, NY US: 	 GHCND:US1NYMR0036
# CHICAGO UNIVERSITY, IL US: 	 GHCND:USW00014892
# DORCHESTER 1.8 ENE, MA US: 	 GHCND:US1MASF0017
# BIG PRAIRIE, OH US: 	 GHCND:USC00330715
# SOUTH WAYNE 3.9 SSW, WI US: 	 GHCND:US1WILF0006
# PLAINFIELD 4.0 NNW, IL US: 	 GHCND:US1ILWL0027
# FRANKLIN TWP 4.4 SE, NJ US: 	 GHCND:US1NJGL0005
# RHINEBECK, NY US: 	 GHCND:USC00307033
# ATWOOD 0.4 N, IL US: 	 GHCND:US1ILPT0011
# SPOT POND, MA US: 	 GHCND:USC00198030
# JEFFERSON, OH US: 	 GHCND:USC00334047
# CHAMPAIGN 1.7 WSW, IL US: 	 GHCND:US1ILCP0039
# MORRIS TWP 0.8 NW, NJ US: 	 GHCND:US1NJMS0003
# BALA CYNWYD 0.8 SSW, PA US: 	 GHCND:US1PAMT0088
# NY CITY CENTRAL PARK, NY US: 	 WBAN:94728
# RATHDRUM 1.4 SSW, ID US: 	 GHCND:US1IDKT0005
# MARBLEHEAD, MA US: 	 GHCND:USC00194502
# DAVENPORT 0.9 SSW, IA US: 	 GHCND:US1IAST0004
# SALEM, IL US: 	 GHCND:USC00117636
# MOUNT LAUREL TWP 0.5 WSW, NJ US: 	 GHCND:US1NJBT0027
# LAKE VIEW, IA US: 	 GHCND:USC00134569
# IPSWICH, MA US: 	 GHCND:USC00193876
# RAY BROOK, NY US: 	 GHCND:USC00306957
# ROCHESTER 0.8 ENE, IL US: 	 GHCND:US1ILSG0043
# MONTCLAIR 0.7 N, NJ US: 	 GHCND:US1NJES0031
# PEORIA 1, IL US: 	 GHCND:USC00116700
# COLD SPRING HARBOR: 	 GHCND:USC00301618
# MCGREGOR, IA US: 	 GHCND:USC00135315
# BELMONT 0.3 SE, MA US: 	 GHCND:US1MAMD0054
# RIVERSIDE 0.2 WNW, IL US: 	 GHCND:US1ILCK0300
# BRADENTON 3.5 WNW, FL US: 	 GHCND:US1FLMA0020
# NEW YORK BOTANICAL GARDEN, NY US: 	 GHCND:USC00305799
# RANTOUL 1.2 NNE, IL US: 	 GHCND:US1ILCP0026
# OCEAN TWP 2.1 WSW, NJ US: 	 GHCND:US1NJMN0073
# DES PLAINES 0.5 NW, IL US: 	 GHCND:US1ILCK0046
# NEW HAVEN 1.7 NW, CT US: 	 GHCND:US1CTNH0013
# QUINCY MEMORIAL BRID, IL US: 	 GHCND:USC00117082
# PALISADES PARK 0.2 WNW, NJ US: 	 GHCND:US1NJBG0018
# GLENCOE 0.1 NW, IL US: 	 GHCND:US1ILCK0053
# NEW YORK FLOYD BENNETT FIELD, NY US: 	 GHCND:USW00014786
# PROSPECT 1.5 NW, CT US: 	 GHCND:US1CTNH0026
# PASADENA, CA US: 	 GHCND:USC00046719
# ALBUQUERQUE 4.7 N, NM US: 	 GHCND:US1NMBR0214
# TORONTO BRIDLEWOOD, CA: 	 GHCND:CA006158408
# WYNDMOOR 0.7 ENE, PA US: 	 GHCND:US1PAMT0008
# ASBURY PARK 0.3 N, NJ US: 	 GHCND:US1NJMN0019
# BENSALEM 1.3 S, PA US: 	 GHCND:US1PABK0024
# SKOKIE N S TREAT WKS, IL US: 	 GHCND:USC00117990
# HELLERTOWN 2.9 ENE, PA US: 	 GHCND:US1PANH0010
# WASHINGTON, CT US: 	 GHCND:USC00068859
# LINDSAY FROST, CA: 	 GHCND:CA006164433
# PRINCETON WATER WORK, NJ US: 	 GHCND:USC00287328
# MILLBROOK, CA: 	 GHCND:CA006155154
# PHILADELPHIA 2.7 WNW, PA US: 	 GHCND:US1PAPH0008
# MILFORD 3.2 W, NH US: 	 GHCND:US1NHHL0039
# CHICAGO WAUKEGAN REGIONAL AIRPORT, IL US: 	 WBAN:14880
# BERWYN 0.7 WNW, PA US: 	 GHCND:US1PACH0042
# OTTAWA U OF O, CA: 	 GHCND:CA006106105
# NORWALK GAS PLANT, CT US: 	 GHCND:USC00065893
# ALTON, CA: 	 GHCND:CA006150243
# OTTSVILLE, PA US: 	 GHCND:USC00366651
# NORTHFIELD 2.8 E, NH US: 	 GHCND:US1NHMR0045
# NEW LONDON 1.0 NNW, CT US: 	 GHCND:US1CTNL0006
# ORANGEVILLE MOE, CA: 	 GHCND:CA006155790
# TENAFLY 1.3 W, NJ US: 	 GHCND:US1NJBG0003
# MINNEDOSA 0.6 WSW, CA: 	 GHCND:CA1MB000226
# BELLEFONTE 1.4 WSW, PA US: 	 GHCND:US1PACN0026
# RANDOLPH 1.4 NE, NH US: 	 GHCND:US1NHCS0010
# MERIDEN, NH US: 	 GHCND:USC00275362
# WAUKON, IA US: 	 GHCND:USC00138755
# WINDSOR 0.2 S, VT US: 	 GHCND:US1VTWR0011
# NEW HAVEN, CT US: 	 GHCND:USC00065266
# EXETER 0.8 WNW, NH US: 	 GHCND:US1NHRC0016
# ARAWANA, CA: 	 GHCND:CA001120M47
# PITTSBURGH 3.6 NNW, PA US: 	 GHCND:US1PAAL0074
# HANOVER 1.4 NNE, NH US: 	 GHCND:US1NHGR0033
# CEDAR RAPIDS 2, IA US: 	 GHCND:USC00131324
# CANTERBURY 0.9 NW, NH US: 	 GHCND:US1NHMR0005
# EDMONTON STONY PLAIN, CA: 	 GHCND:CA00301222F
# DURHAM 7.5 NNE, NC US: 	 GHCND:US1NCDH0062
# SHEBOYGAN CO MEMORIAL AIRPORT, WI US: 	 WBAN:04841
# CANFIELD 1 S, OH US: 	 GHCND:USC00331245
# BELLEVUE OFFUTT AFB, NE US: 	 WBAN:14949
# FORT EDMONTON, CA: 	 GHCND:CA003012659
# WATERFORD 2.6 N, MI US: 	 GHCND:US1MIOK0031
# SHOREWOOD, WI US: 	 GHCND:USC00477792
# SIDNEY 1 S, OH US: 	 GHCND:USC00337693
# LINCOLN 3.9 W, NE US: 	 GHCND:US10lanc067
# LIMA LAKE DRAIN DIST, IL US: 	 GHCND:USC00115074
# PORTLAND 0.9 S, CT US: 	 GHCND:US1CTMD0002
# CARSONVILLE, MI US: 	 GHCND:USC00201331
# MADISON WEATHER BUREAU CITY, WI US: 	 GHCND:USC00474966
# SISTERSVILLE 6.1 ESE, WV US: 	 GHCND:US1WVTY0004
# BOZEMAN 6 W EXPERIMENTAL FARM, MT US: 	 GHCND:USC00241047
# SOUTH PORTLAND 1.7 S, ME US: 	 GHCND:US1MECM0128
# BRISTOL 3 W, CT US: 	 GHCND:USC00060830
# ELKHORN 0.4 ESE, WI US: 	 GHCND:US1WIWW0012
# RED WING 4.4 SE, MN US: 	 GHCND:US1MNGH0001
# SHREWSBURY 1.6 NNE, MA US: 	 GHCND:US1MAWR0030
# RAYMOND, WI US: 	 GHCND:USC00476970
# KENTFIELD, CA US: 	 GHCND:USC00044500
# NORWICH, VT US: 	 GHCND:USC00436020
# PENNOCK 6.7 N, MN US: 	 GHCND:US1MNKD0004
# WOODS HOLE GOLF CLUB, MA US: 	 GHCND:USC00199891
# KEENE 1.9 SE, NH US: 	 GHCND:US1NHCH0026
# BURLINGTON 0.4 W, VT US: 	 GHCND:US1VTCH0020
# FLORISSANT 2.5 NE, MO US: 	 GHCND:US1MOSL0055
# CHULA VISTA, CA US: 	 GHCND:USC00041758
# COON RAPIDS 1.4 ESE, MN US: 	 GHCND:US1MNAA0013
# SEATTLE 4.2 SW, WA US: 	 GHCND:US1WAKG0072
# NEW ROCHELLE 1.3 S, NY US: 	 GHCND:US1NYWC0009
# KNOXVILLE 8.0 WSW, TN US: 	 GHCND:US1TNKX0041
# UNITY VILLAGE, MO US: 	 GHCND:USC00238524
# ARROYO SECO RANGER STATION FC508, CA US: 	 GHCND:USC00040327
# SPRING PARK 0.2 SSE, MN US: 	 GHCND:US1MNHN0083
# KENNEBEC, SD US: 	 GHCND:USC00394516
# LOWELL, MA US: 	 GHCND:USC00194313
# CONCORDIA, MO US: 	 GHCND:USC00231837
# MEDFORD, MA US: 	 GHCND:USC00194615
# TORONTO GLENVIEW, CA: 	 GHCND:CA006158567
# WOONSOCKET 0.3 W, RI US: 	 GHCND:US1RIPR0010
# SIOUX FALLS, SD US: 	 NEXRAD:KFSD
# GREENVILLE, RI US: 	 GHCND:USC00373306
# WINDSOR FORD PLANT, US: 	 GHCND:CA006139533
# SUMMERVILLE 0.9 NNW, SC US: 	 GHCND:US1SCDC0035
# RADNOR TOWNSHIP 2.1 N, PA US: 	 GHCND:US1PADL0005
# MINNEAPOLIS NUMBER 1, MN US: 	 GHCND:USC00215424
# CAMBRIDGE MIT, MA US: 	 GHCND:USC00191110
# DUXBURY 3.7 W, MA US: 	 GHCND:US1MAPL0030
# LABADIEVILLE 0.9 NNW, LA US: 	 GHCND:US1LAAP0001
# CHESTNUT HILL, MA US: 	 GHCND:USC00191447
# MOUNT SINAI 0.4 SW, NY US: 	 GHCND:US1NYSF0090
# VERNON SOUTHWEST, CA: 	 GHCND:CA001128585
# MADISON 3.7 ENE, MS US: 	 GHCND:US1MSMD0020
# GENEVA EXPERIMENT ST, NY US: 	 GHCND:USC00303177
# PARKERSBURG AIRPORT, WV US: 	 WBAN:03804
# MONTAUK, NY US: 	 GHCND:USC00305441
# LA CROSSE, WI US: 	 NEXRAD:KARX
# BURLINGTON JUNCTION, MO US: 	 GHCND:USC00231141
# CAMPBELLSVILLE 2 SSW, KY US: 	 GHCND:USC00151256
# APPLETON 0.9 W, WI US: 	 GHCND:US1WIOG0015
# CAMERON, MO US: 	 GHCND:USC00231216
# INDEPENDENCE, KS US: 	 GHCND:USC00143954
# NEW YORK WESTERLEIGH, NY US: 	 GHCND:USC00305821
# WHITE ROCK CAMPBELL SCIENTIFIC, CA: 	 GHCND:CA001108910
# ABILENE 0.7 E, KS US: 	 GHCND:US1KSDK0012
# NEW YORK 8.8 N, NY US: 	 GHCND:US1NYNY0074
# WEST BARNET, VT US: 	 COOP:438959
# DEARBORN NUMBER 2, MI US: 	 GHCND:USC00202016
# PARSIPPANY TROY HILLS TWP 2.1, NJ US: 	 GHCND:US1NJMS0036
# SAINT JOHNSBURY, VT US: 	 GHCND:USC00437054
# WOBURN 0.5 NW, MA US: 	 GHCND:US1MAMD0087
# RUTLAND 3.1 SW, MA US: 	 GHCND:US1MAWR0063
# PLAINFIELD, NJ US: 	 GHCND:USC00287079
# ST. ALBANS 0.5 NE, VT US: 	 GHCND:US1VTFR0009
# MOUNT CARMEL, IL US: 	 GHCND:USC00115888
# BETHEL, VT US: 	 GHCND:USC00430660
# DAVISON ARMY AIR FIELD, VA US: 	 WBAN:93728
# SQUANTUM NAS, MA US: 	 GHCND:USW00014789
# HACKETTSTOWN 0.1 SW, NJ US: 	 GHCND:US1NJWR0029
# HARRISON, NJ US: 	 GHCND:USC00283704
# PROVIDENCE, RI US: 	 WBAN:14765
# KALAMAZOO, MI US: 	 GHCND:USC00204239
# DIGHTON 1.1 WSW, MA US: 	 GHCND:US1MABR0008
# WHITE LAKE 3.2 N, MI US: 	 GHCND:US1MIOK0093
# LA GRANGE, IL US: 	 GHCND:USC00114816
# BENZONIA, MI US: 	 GHCND:USC00200715
# MEDORA, IN US: 	 GHCND:USC00125541
# BLANCHARD, ME US: 	 GHCND:USC00170655
# FLUSHING, NY US: 	 GHCND:USC00302868
# ROBERTS DAM, MA US: 	 GHCND:USC00196915
# BRISTOL 2.7 NNE, CT US: 	 GHCND:US1CTHR0071
# WILMINGTON 2 W, NY US: 	 GHCND:USC00309499
# GRINNELL 0.6 NW, IA US: 	 GHCND:US1IAPW0004
# WOODLANDS ARDSLEY, NY US: 	 GHCND:USC00309576
# SANTA BARBARA 3.0 W, CA US: 	 GHCND:US1CASB0017
# GLOVERSVILLE, NY US: 	 GHCND:USC00303319
# PENSACOLA CORRY FIELD NAAS, FL US: 	 GHCND:USW00093828
# BARNSTABLE 0.7 NE, MA US: 	 GHCND:US1MABA0076
# CHARLOTTETOWN, CA: 	 GHCND:CA008300298
# ROCKPORT 1 ESE, MA US: 	 GHCND:USC00196977
# ROCK SPRINGS 2.8 WSW, WI US: 	 GHCND:US1WISK0002
# KEYSTONE HEIGHTS 2.3 SSE, FL US: 	 GHCND:US1FLCY0023
# APALACHICOLA 0.8 WNW, FL US: 	 GHCND:US1FLFR0002
# HARTFORD BRAINARD FIELD, CT US: 	 WBAN:14752
# AURORA 2.8 ESE, NY US: 	 GHCND:US1NYCY0001
# BARRINGTON 1.3 WNW, RI US: 	 GHCND:US1RIBR0005
# LITITZ 4.5 N, PA US: 	 GHCND:US1PALB0006
# HARKNESS, NY US: 	 GHCND:USC00303662
# SPRINGS 1 SW, PA US: 	 GHCND:USC00368395
# KENNETT SQUARE, PA US: 	 GHCND:USC00364533
# WORCESTER C, MA US: 	 GHCND:USC00199936
# WEST GROTON, MA US: 	 GHCND:USC00199226
# RUTHERFORD 1.2 N, NJ US: 	 GHCND:US1NJBG0013
# LEICESTER, MA US: 	 GHCND:USC00194125
# PITTSBURGH 1.6 SW, PA US: 	 GHCND:US1PAAL0014
# COLUMBIA, PA US: 	 GHCND:USC00361675
# HODGES VILLAGE DAM, MA US: 	 COOP:193659
# VERNON, CA: 	 GHCND:CA001128551
# ASTON 0.2 W, PA US: 	 GHCND:US1PADL0009
# FITCHBURG C, MA US: 	 GHCND:USC00192812
# NANTUCKET 2.2 E, MA US: 	 GHCND:US1MANT0002
# BURLINGTON, PA US: 	 GHCND:USC00281211
# VICTOR 2 NW, NY US: 	 GHCND:USC00308839
# OMRO 2.3 WSW, WI US: 	 GHCND:US1WIWN0007
# PHILADELPHIA 2.1 NE, PA US: 	 GHCND:US1PAPH0012
# HENDERSONVILLE 3.0 NNW, NC US: 	 GHCND:US1NCHN0005
# DOYLESTOWN AIRPORT, PA US: 	 WBAN:54786
# MAYNARD 2, MA US: 	 GHCND:USC00194580
# MARYSVILLE 6.4 NW, WA US: 	 GHCND:US1WASN0006
# SARANAC LAKE, NY US: 	 GHCND:USC00307472
# NETHER PROVIDENCE TOWNSHIP 0.4, PA US: 	 GHCND:US1PADL0003
# OCEANSIDE, NY US: 	 GHCND:USC00306138
# BEVERLY 2.8 NW, MA US: 	 GHCND:US1MAES0002
# PLYMOUTH 6.6 SE, MA US: 	 GHCND:US1MAPL0039
# LEWES 0.8 SE, DE US: 	 GHCND:US1DESS0004
# MACTAQUAC PROV PARK, CA: 	 GHCND:CA008102536
# WEPAWAUG RESERVOIR, CT US: 	 GHCND:USC00069007
# NAPA, CA US: 	 GHCND:USC00046065
# WEST CHESTER 2 W, PA US: 	 GHCND:USC00369465
# BROOKLYN 1, NY US: 	 GHCND:USC00300958
# LEWISTON 1 N, US: 	 GHCND:USC00304715
# GARRETTSVILLE, OH US: 	 GHCND:USC00333085
# ARKWRIGHT, NY US: 	 GHCND:USC00300259
# WEST HAVEN 0.8 W, CT US: 	 GHCND:US1CTNH0039
# LEOMINSTER, MA US: 	 GHCND:USC00194135
# MONROE 1.7 SE, NY US: 	 GHCND:US1NYOR0006
# EAST ROCHESTER 0.3 SE, NY US: 	 GHCND:US1NYMR0004
# WAUPACA, WI US: 	 GHCND:USC00478951
# EASTCHESTER, NY US: 	 GHCND:USC00302291
# EAST HAVEN 3.5 SSW, CT US: 	 GHCND:US1CTNH0021
# RANDOLPH CENTER, VT US: 	 GHCND:USC00436717
# HAMILTON TWP 2.8 WSW, NJ US: 	 GHCND:US1NJMC0032
# EAST HAVEN SALTONSTA, CT US: 	 GHCND:USC00062169
# EDGARTOWN, MA US: 	 GHCND:USC00192501
# PENNSAUKEN 1 N, NJ US: 	 GHCND:USC00286864
# HARTFORD, CT US: 	 GHCND:USC00063446
# BEAUFORT 0.3 N, SC US: 	 GHCND:US1SCBF0078
# RIVERTON 0.3 SSW, NJ US: 	 GHCND:US1NJBT0071
# LITTLETON, CO US: 	 GHCND:USC00055056
# DAVIS 0.5 N, IL US: 	 GHCND:US1ILSP0007
# LAKEWOOD 2 ENE, NJ US: 	 GHCND:USC00284627
# CHALMETTE, LA US: 	 GHCND:USC00161639
# EAST BRIDGEWATER 0.3 WSW, MA US: 	 GHCND:US1MAPL0022
# PONTCHARTRAIN GROVE: 	 GHCND:USC00167427
# CHELTENHAM 1 NW, MD US: 	 GHCND:USC00181710
# ATLANTA HARTSFIELD INTERNATIONAL AIRPORT, GA US: 	 WBAN:13874
# LAWRENCE 1.8 NNW, KS US: 	 GHCND:US1KSDG0064
# CLAY CENTER 0.4 NNW, KS US: 	 GHCND:US1KSCY0011
# RUSSELLVILLE 0.9 NNE, IN US: 	 GHCND:US1INMY0005
# ALEXANDRIA 2.4 NE, VA US: 	 GHCND:US1VAAR0005
# KEWANEE BAKER PARK, IL US: 	 GHCND:USC00114715
# CHICAGO BOTANIC GARDEN, IL US: 	 GHCND:USC00111497
# PALO ALTO 0.8 NNE, CA US: 	 GHCND:US1CASC0028
# DECORAH 7.9 ENE, IA US: 	 GHCND:US1IAWH0001
# ATLANTA WEATHER BUREAU CITY, GA US: 	 GHCND:USC00090456
# EARLVILLE 3 S, IL US: 	 GHCND:USC00112510
# MIAMI BAYFRONT PARK: 	 GHCND:USC00085653
# GLEN ELLYN 1.3 NNW, IL US: 	 GHCND:US1ILDP0108
# PORTLAND: 	 GHCND:USC00176902
# FARMINGTON, ME US: 	 GHCND:USC00172765
# LYONS 0.7 NNE, NY US: 	 GHCND:US1NYWN0023
# PHILADELPHIA 1.4 SE, MS US: 	 GHCND:US1MSNS0008
# CHENEY, WA US: 	 GHCND:USC00451362
# ST LOUIS UNIVERSITY, MO US: 	 GHCND:USC00237465
# NEW HAVEN 2.4 SE, VT US: 	 GHCND:US1VTAD0019
# NORTH WILDWOOD 0.4 SE, NJ US: 	 GHCND:US1NJCM0028
# BRATTLEBORO 3.1 SW, VT US: 	 GHCND:US1VTWH0004
# PUEBLO 7.0 ESE, CO US: 	 GHCND:US1COPU0091
# PROVO BYU, UT US: 	 GHCND:USC00427064
# VERSAILLES 1.7 WSW, KY US: 	 GHCND:US1KYWF0001
# EDEN PRAIRIE 2.3 WNW, MN US: 	 GHCND:US1MNHN0047
# KNICKERBOCKER, TX US: 	 GHCND:USC00414848
# OLD BROWNSBORO PLACE 0.3 SW, KY US: 	 GHCND:US1KYJF0002
# WEST LAFAYETTE 0.9 N, IN US: 	 GHCND:US1INTP0013
# PACIFIC GROVE 0.7 ESE, CA US: 	 GHCND:US1CAMT0004
# SYRACUSE HANCOCK INTERNATIONAL AIRPORT, NY US: 	 WBAN:14771
# SHELTER ISLAND HEIGHTS 2.1 SSW, NY US: 	 GHCND:US1NYSF0070
# CANTON REPOSITORY, OH US: 	 GHCND:USC00331250
# GENEVA 3 S, OH US: 	 GHCND:USC00333095
# GERMANTOWN 3 NE, OH US: 	 GHCND:USC00333125
# RICHMOND WATERWORKS, IN US: 	 GHCND:USC00127362
# LAWSHE, OH US: 	 GHCND:USC00334440
# XENIA 1.3 WSW, OH US: 	 GHCND:US1OHGR0003
# MANVILLE 0.2 NE, RI US: 	 GHCND:US1RIPR0015
# SUMMERTON 5.2 SSE, SC US: 	 GHCND:US1SCCD0004
# ELK POINT 13 NE, SD US: 	 GHCND:USC00392622
# ESSEX JUNCTION, VT US: 	 GHCND:USC00432828
# RUTLAND STATE AIRPORT, VT US: 	 WBAN:94737
# OLYMPIA PRIEST PT PA, WA US: 	 GHCND:USC00456109
# HUNTSVILLE, WA US: 	 GHCND:USC00453858
# BARABOO RIVER, WI US: 	 GHCND:USC00470519
# SEATTLE CITY OFFICE, WA US: 	 COOP:457488
# MANITOWOC 1.9 NNW, WI US: 	 GHCND:US1WIMC0008
# GIBBSVILLE, WI US: 	 GHCND:USC00473116
# FONTANA, WI US: 	 GHCND:USC00478872
# WESTFIELD, WI US: 	 GHCND:USC00479095
# PRINCETON 3.4 SE, WI US: 	 GHCND:US1WIGL0002
# WESTMINSTER, CA: 	 GHCND:CA006149454
# KIMBALL 0.3 WNW, TN US: 	 GHCND:US1TNMA0011
# TUCSON 2.5 WNW, AZ US: 	 GHCND:US1AZPM0051
# FULLERTON MUNICIPAL AIRPORT, CA US: 	 WBAN:03166
# MILL CREEK RANGER STATION, CA US: 	 COOP:045635
# BOULDER 1.3 NW, CO US: 	 GHCND:US1COBO0072
# DARIEN 3.6 N, CT US: 	 GHCND:US1CTFR0005
# DAYTONA BEACH, FL US: 	 GHCND:USC00082150
# DE FUNIAK SPRINGS 1 E, FL US: 	 GHCND:USC00082220
# CEDAR RAPIDS NUMBER 1, IA US: 	 GHCND:USC00131319
# ELY 0.5 SE, IA US: 	 GHCND:US1IALN0003
# SIOUX CITY 0.7 NW, IA US: 	 GHCND:US1IAWD0007
# STAUNTON 1.5 WSW, IL US: 	 GHCND:US1ILMP0006
# WICHITA, KS US: 	 NEXRAD:KICT
# KB9MYL RICHMOND 4.9 NNW, IN US: 	 GHCND:US1INWN0016
# FRENCHBURG 2 W, KY US: 	 GHCND:USC00153052
# MANCHESTER: 	 GHCND:USC00194405
# MARSHFIELD MUNICIPAL AIRPORT, MA US: 	 WBAN:64774
# BELMONT, MA US: 	 GHCND:USC00190582
# STOUGHTON 1.2 E, MA US: 	 GHCND:US1MANF0031
# CAMBRIDGE WATER TREATMENT, MD US: 	 GHCND:USC00181385
# PRINCESS ANNE 0.5 SSW, MD US: 	 GHCND:US1MDSS0011
# MUNITH 5 SW, MI US: 	 GHCND:USC00205698
# HARBERT, MI US: 	 GHCND:USC00203576
# MINNEAPOLIS NAS, MN US: 	 GHCND:USW00014947
# WOODVILLE 4 ESE, MS US: 	 GHCND:USC00229793
# ST CHARLES 7 SSW, MO US: 	 GHCND:USC00237398
# FARGO HECTOR INTERNATIONAL AIRPORT, ND US: 	 WBAN:14914
# BERNARDSVILLE 0.2 WNW, NJ US: 	 GHCND:US1NJSM0028
# CHERRY HILL, NJ US: 	 GHCND:USC00281608
# BAINBRIDGE 6.5 SSE, NY US: 	 GHCND:US1NYCN0018
# GRAND ISLAND, NY US: 	 GHCND:USC00303381
# CENTER MORICHES 0.5 N, NY US: 	 GHCND:US1NYSF0123
# NIAGARA FALLS 0.7 WNW, NY US: 	 GHCND:US1NYNG0011
# BINGHAMTON 2.7 N, NY US: 	 GHCND:US1NYBM0037
# PULASKI 0.5 NE, NY US: 	 GHCND:US1NYOS0021
# CHESTERLAND 2.3 NNW, OH US: 	 GHCND:US1OHGG0015
# GREENVILLE HIGHWAY DEP, OH US: 	 GHCND:USC00333380
# SALEM 1.0 NNE, OH US: 	 GHCND:US1OHCB0002
# CRANSTON 4.1 E, RI US: 	 GHCND:US1RIPR0017
# NEW TAZEWELL, TN US: 	 GHCND:USC00406562
# CHESAPEAKE 9.8 NW, VA US: 	 GHCND:US1VACSC004
# BRYN MAWR SKYWAY 0.9 N, WA US: 	 GHCND:US1WAKG0074
# LODI, WI US: 	 GHCND:USC00474790
# HORICON 2.1 ENE, WI US: 	 GHCND:US1WIDD0003
# SUPERIOR RICHARD I BONG AIRPORT, WI US: 	 WBAN:54908
# MENOMONIE, WI US: 	 GHCND:USC00475335
# WAUWATOSA 1.9 E, WI US: 	 GHCND:US1WIMW0046
# MATCHAYAW LAKE, CA: 	 GHCND:CA003014235
# MONTICELLO MUNICIPAL AIRPORT, AR US: 	 WBAN:53919
# ORACLE 1.1 WSW, AZ US: 	 GHCND:US1AZPN0049
# MARYSVILLE 5.0 N, CA US: 	 GHCND:US1CAYB0003
# GEORGETOWN 1.0 SSW, CO US: 	 GHCND:US1COCC0013
# NEW CANAAN 3.8 N, CT US: 	 GHCND:US1CTFR0059
# RIDGEFIELD 3.6 N, CT US: 	 GHCND:US1CTFR0058
# SOUTHINGTON 1.0 ENE, CT US: 	 GHCND:US1CTHR0076
# WEST HARTFORD 1.1 W, CT US: 	 GHCND:US1CTHR0049
# NEW SMYRNA BEACH 4.0 SE, FL US: 	 GHCND:US1FLVL0020
# WINDSOR LOCKS 2.5 W, CT US: 	 GHCND:US1CTHR0061
# JACKSONVILLE 10.2 ENE, FL US: 	 GHCND:US1FLDV0070
# WINDSOR HEIGHTS 0.8 SE, IA US: 	 GHCND:US1IAPK0037
# SAVANNA TRI TOWNSHIP AIRPORT, IL US: 	 WBAN:04996
# SPRINGFIELD, IL US: 	 GHCND:USC00118184
# PECATONICA 1.9 NE, IL US: 	 GHCND:US1ILWN0020
# MONTICELLO 5.6 NNE, IL US: 	 GHCND:US1ILPT0012
# FORT WAYNE 8.5 N, IN US: 	 GHCND:US1INAL0035
# CAMBRIDGE CITY 3 N, IN US: 	 GHCND:USC00121229
# COHASSET, MA US: 	 GHCND:USC00191582
# INDIANAPOLIS 10.0 NE, IN US: 	 GHCND:US1INMR0082
# GUILFORD 0.9 NW, NY US: 	 GHCND:US1NYCN0013
# EAST GLOUCESTER, MA US: 	 GHCND:USC00192150
# LUNENBURG 0.6 NE, MA US: 	 GHCND:US1MAWR0058
# BRIGHTON 0.5 W, MA US: 	 GHCND:US1MASF0004
# SCITUATE 1.2 NW, MA US: 	 GHCND:US1MAPL0037
# RANDOLPH, MA US: 	 GHCND:USC00196770
# GLOUCESTER 1.2 WSW, MA US: 	 GHCND:US1MAES0049
# EAST BRIMFIELD LAKE, MA US: 	 GHCND:USC00192107
# TOWSON 0.8 SW, MD US: 	 GHCND:US1MDBL0016
# LAWTON 1.6 S, MI US: 	 GHCND:US1MIVB0007
# SEVERNA PARK 1.9 W, MD US: 	 GHCND:US1MDAA0066
# GRAND JUNCTION, MI US: 	 GHCND:USC00203303
# SOUTH HAVEN, MI US: 	 GHCND:USC00207690
# OSLO 2.7 WNW, ND US: 	 GHCND:US1NDWH0002
# MARYVILLE 1.4 SSW, MO US: 	 GHCND:US1MOFSA147
# LIVINGSTON, MT US: 	 GHCND:USC00245076
# LOUISBURG, NC US: 	 GHCND:USC00315123
# MANTUA TWP 1.5 E, NJ US: 	 GHCND:US1NJGL0004
# LONG BRANCH 1.7 SSW, NJ US: 	 GHCND:US1NJMN0069
# DEMAREST 0.6 NNW, NJ US: 	 GHCND:US1NJBG0031
# WESTFIELD 0.6 NE, NJ US: 	 GHCND:US1NJUN0014
# GROTON 0.6 ESE, NY US: 	 GHCND:US1NYTM0007
# HAMBURG 0.3 ESE, NY US: 	 GHCND:US1NYER0125
# JFK INTERNATIONAL AIRPORT, NY US: 	 WBAN:94789
# VALLEY STREAM 0.6 SE, NY US: 	 GHCND:US1NYNS0035
# WATERLOO, NY US: 	 GHCND:USC00308987
# STATEN ISLAND 1.4 SE, NY US: 	 GHCND:US1NYRC0002
# CHATFIELD, OH US: 	 GHCND:USC00331492
# WATKINS GLEN 3.9 W, NY US: 	 GHCND:US1NYSY0010
# RICHMOND HEIGHTS 0.4 NNE, OH US: 	 GHCND:US1OHCY0004
# MILLPORT 2 NW, OH US: 	 GHCND:USC00335315
# COLUMBUS RICKENBACKER, OH US: 	 WBAN:13812
# MILLERSBURG, OH US: 	 GHCND:USC00335297
# TONKAWA 0.4 SSW, OK US: 	 GHCND:US1OKKY0004
# CAMP HILL, PA US: 	 GHCND:USC00361198
# SAYRE 0.7 S, PA US: 	 GHCND:US1PABF0020
# GLENSHAW 1.3 NW, PA US: 	 GHCND:US1PAAL0016
# MOUNT PLEASANT 7.9 NNE, SC US: 	 GHCND:US1SCCR0015
# MOUNT PLEASANT 1.6 S, SC US: 	 GHCND:US1SCCR0161
# LACKLAND AFB 3.5 SSE, TX US: 	 GHCND:US1TXBXR015
# WALKERTON 2 NW, VA US: 	 GHCND:USC00448829
# PULASKI 2 E, VA US: 	 GHCND:USC00446955
# PLYMOUTH, VT US: 	 GHCND:USC00436438
# COTTAGE GROVE, WI US: 	 GHCND:USC00471840
# WILLIAMS BAY, WI US: 	 GHCND:USC00479226
# HARTLAND, WI US: 	 GHCND:USC00473461
# TOMAHAWK REGIONAL AIRPORT, WI US: 	 WBAN:54953
# WHITEWATER 1.3 NW, WI US: 	 GHCND:US1WIJF0005
# VANCOUVER MOUNT PLEASANT, CA: 	 GHCND:CA001108460
# GUELPH OAC, CA: 	 GHCND:CA006143083
# SHELBURNE WPCP, CA: 	 GHCND:CA006147693
# CULVER CITY, CA US: 	 GHCND:USC00042214
# CLOVIS 3.6 NE, CA US: 	 GHCND:US1CAFR0031
# HAVANA 4.2 SW, FL US: 	 GHCND:US1FLGD0002
# DECATUR 1.8 WSW, IL US: 	 GHCND:US1ILMA0022
# CHARLESTOWN 1.5 ENE, IN US: 	 GHCND:US1INCK0009
# KOKOMO 0.6 S, IN US: 	 GHCND:US1INHW0011
# SEYMOUR HIGHWAY GARAGE, IN US: 	 GHCND:USC00127930
# VINCENNES 1.0 SE, IN US: 	 GHCND:US1INKN0005
# STANTON 0.3 W, KY US: 	 GHCND:US1KYPW0002
# BRIDGEWATER 0.1 ESE, MA US: 	 GHCND:US1MAPL0021
# MYSTIC LAKE, MA US: 	 GHCND:USC00195095
# GLEN ECHO, MD : 	 GHCND:USC00183645
# SUITLAND, MD US: 	 GHCND:USC00188656
# LEWISTON, ME US: 	 GHCND:USC00174566
# ANN ARBOR NEAR, MI US: 	 GHCND:USC00200224
# HILLSDALE, MI US: 	 GHCND:USC00203823
# ROYALTON 5 W, MN US: 	 GHCND:USC00217157
# PRENTISS, MS US: 	 GHCND:USC00227172
# GREAT FALLS 2.4 SW, MT US: 	 GHCND:US1MTCC0004
# WHISPERING PINES 1.6 ESE, NC US: 	 GHCND:US1NCMR0025
# ANTRIM, NH US: 	 GHCND:USC00270215
# BRIDGETON 2.2 N, NJ US: 	 GHCND:US1NJCD0007
# GLENHAM, NY US: 	 GHCND:USC00303259
# BRONX 1.5 NE, NY US: 	 GHCND:US1NYBX0025
# HARRISON 4.1 SSW, NY US: 	 GHCND:US1NYWC0005
# CATTARAUGUS, NY US: 	 GHCND:USC00305673
# WHITESVILLE 1 N, NY US: 	 GHCND:USC00309425
# ELLSWORTH, OH US: 	 GHCND:USC00332580
# CHARDON, OH US: 	 GHCND:USC00331458
# SUMMERSIDE 2.1 SE, OH US: 	 GHCND:US1OHCM0008
# TAPPAN DAM, OH US: 	 GHCND:USC00338240
# HURON 0.2 SW, OH US: 	 GHCND:US1OHER0017
# FURLONG 0.7 SW, PA US: 	 GHCND:US1PABK0015
# CHESTER, PA US: 	 GHCND:USC00361423
# READING 2.9 ESE, PA US: 	 GHCND:US1PABR0036
# POINT JUDITH, RI US: 	 GHCND:USC00376450
# EASLEY 1.3 S, SC US: 	 GHCND:US1SCPC0014
# MARION 1 WNW, SC US: 	 GHCND:USC00385514
# COLLEGEPORT: 	 GHCND:USC00411885
# HANOVER 5.9 ESE, VA US: 	 GHCND:US1VAKW0002
# BENNINGTON MORSE STATE AIRPORT, VT US: 	 WBAN:54781
# MARSHFIELD, VT US: 	 GHCND:USC00434999
# RICE LAKE, WI US: 	 GHCND:USC00477132
# CLINTON 0.4 NNW, WI US: 	 GHCND:US1WIRK0002
# BERLIN LOCK, WI US: 	 GHCND:USC00470735
# DARLINGTON, WI US: 	 GHCND:USC00472001
# GREEN LAKE 0.8 E, WI US: 	 GHCND:US1WIGL0004
# JOHNSON CREEK 2.7 SSW, WI US: 	 GHCND:US1WIJF0017
# COLORADO SPRINGS 2.8 SSE, CO US: 	 GHCND:US1COEP0314
# LITTLETON 6.0 WSW, CO US: 	 GHCND:US1COJF0227
# NEW CANAAN 1.9 ENE, CT US: 	 GHCND:US1CTFR0003
# CARROLLWOOD 2.0 SSE, FL US: 	 GHCND:US1FLHB0039
# DE LAND 0.6 SSE, FL US: 	 GHCND:US1FLVL0070
# SAINT JAMES CITY 0.4 SSE, FL US: 	 GHCND:US1FLLE0022
# HAVANA, IL US: 	 GHCND:USC00113940
# MERIDIAN 1 W, ID US: 	 GHCND:USC00105841
# BANNOCKBURN 0.5 ESE, IL US: 	 GHCND:US1ILLK0015
# LE CLAIRE 1.8 NNE, IA US: 	 GHCND:US1IAST0001
# HAMMOND 0.6 SSW, IN US: 	 GHCND:US1INLK0089
# PLYMOUTH MUNICIPAL AIRPORT, MA US: 	 WBAN:54769
# LEOMINSTER 1.5 S, MA US: 	 GHCND:US1MAWR0013
# HARVARD FOREST, MA US: 	 GHCND:USC00193429
# WASHINGTON 3.0 ENE, DC US: 	 GHCND:US1DCDC0001
# KENSINGTON 0.1 W, MD US: 	 GHCND:US1MDMG0040
# ST. PETER, MN US: 	 GHCND:USC00217405
# FAYETTE EXPERIMENTAL LAGOON, MO US: 	 GHCND:USC00232828
# MARSHALL 1.0 NNW, MO US: 	 GHCND:US1MOFSA195
# CHOTEAU, MT US: 	 GHCND:USC00241737
# CHESTERFIELD TWP 0.4 ESE, NJ US: 	 GHCND:US1NJBT0007
# ORANGE, NJ US: 	 GHCND:USC00286560
# WESTFIELD, NJ US: 	 GHCND:USC00289455
# WILLARD, NY US: 	 GHCND:USC00309457
# HELMUTH FIRE CONTROL, NY US: 	 GHCND:USC00303769
# QUEENS 2.1 NE, NY US: 	 GHCND:US1NYQN0029
# NAPLES, NY US: 	 GHCND:USC00305635
# WILTON 3.4 S, NY US: 	 GHCND:US1NYSR0023
# CHILLICOTHE 3.7 S, OH US: 	 GHCND:US1OHRS0001
# MOUNT HOPE, NY US: 	 GHCND:USC00305540
# CANFIELD 0.5 N, OH US: 	 GHCND:US1OHMH0011
# DELPHOS 2.3 ESE, OH US: 	 GHCND:US1OHAL0008
# EAST LIBERTY 4.2 SSE, OH US: 	 GHCND:US1OHLG0002
# HILLSBORO 0.8 SSW, OH US: 	 GHCND:US1OHHG0003
# KINGSVILLE, OH US: 	 GHCND:USC00334242
# MOUNT VERNON, OH US: 	 GHCND:USC00335585
# NORWALK MILAN, OH US: 	 COOP:336128
# MECCA, OH US: 	 GHCND:USC00335090
# CORVALLIS, OR US: 	 WBAN:24202
# EUGENE 3.6 WNW, OR US: 	 GHCND:US1ORLA0014
# CANBY 5.4 SE, OR US: 	 GHCND:US1ORCC0020
# PITTSBURGH 2.8 NE, PA US: 	 GHCND:US1PAAL0046
# SENECA 0.7 NNE, PA US: 	 GHCND:US1PAVN0005
# NORRISTOWN, PA US: 	 GHCND:USC00366370
# WILLIAMSPORT REGIONAL AIRPORT, PA US: 	 WBAN:14778
# CRANSTON 1.2 SSE, RI US: 	 GHCND:US1RIPR0057
# AIKEN 8.3 E, SC US: 	 GHCND:US1SCAK0033
# FALFURRIAS 0.4 WNW, TX US: 	 GHCND:US1TXBRK005
# LAWRENCEVILLE 3 E, VA US: 	 GHCND:USC00444768
# SPOKANE 5.0 N, WA US: 	 GHCND:US1WASP0030
# JANESVILLE 2.7 ENE, WI US: 	 GHCND:US1WIRK0016
# UNION GROVE 0.4 NNW, WI US: 	 GHCND:US1WIRC0013
# SAUK CITY 1.0 NW, WI US: 	 GHCND:US1WISK0003
# COLBY 2 S, WI US: 	 GHCND:USC00471720
# SPARTA 0.8 NNE, WI US: 	 GHCND:US1WIMN0003
# CHARLESTON 3.9 WSW, WV US: 	 GHCND:US1WVKN0021
# LEWISBURG 3 N, WV US: 	 GHCND:USC00465224
# YARMOUTH RCS, CA: 	 GHCND:CA008206491
# ARNPRIOR, CA: 	 GHCND:CA006100340
# PORT DOVER, CA: 	 GHCND:CA006136643
# LASHBURN 1, CA: 	 GHCND:CA004044155
# CODEN, AL US: 	 GHCND:USC00011803
# JOICE ISLAND, CA US: 	 GHCND:USC00044392
# ASPEN 5.8 NW, CO US: 	 GHCND:US1COPT0012
# IGOR I SIKORSKY MEMORI AIRPORT, CT US: 	 WBAN:94702
# SAVANNAH NWR SOUTH CAROLINA, GA : 	 GHCND:USR0000SSAV
# WALLINGFORD 5.2 E, IA US: 	 GHCND:US1IAEM0001
# PRIEST RIVER 2.0 ENE, ID US: 	 GHCND:US1IDBR0009
# MOSCOW 1.3 SW, ID US: 	 GHCND:US1IDLT0003
# GENESEO, IL US: 	 GHCND:USC00113384
# LEWISTOWN, IL US: 	 GHCND:USC00115038
# NEWBERRY, IN US: 	 GHCND:USC00126131
# WATERLOO HIGHWAY GAR, IN US: 	 GHCND:USC00129276
# GREAT BARRINGTON 0.4 N, MA US: 	 GHCND:US1MABE0002
# PITTSFIELD, MA US: 	 GHCND:USC00196409
# WASHINGTON 5.1 NW, DC US: 	 GHCND:US1DCDC0014
# NORWAY 0.5 E, ME US: 	 GHCND:US1MEOX0021
# BATTLE CREEK 5 NW, MI US: 	 GHCND:USC00200552
# BLOOMINGTON 1.2 SSE, MN US: 	 GHCND:US1MNHN0066
# FAIRMONT, MN US: 	 GHCND:USC00212698
# CHILLICOTHE RADIO KCHI, MO US: 	 GHCND:USW00013982
# BOONE, NC US: 	 GHCND:USC00310982
# MENDHAM 1.5 W, NJ US: 	 GHCND:US1NJMS0082
# WAYNE, NJ US: 	 GHCND:USC00289317
# AMITYVILLE 0.6 NNE, NY US: 	 GHCND:US1NYSF0092
# FLORAL PARK 0.7 ESE, NY US: 	 GHCND:US1NYNS0022
# SADDLE ROCK 3.4 WSW, NY US: 	 GHCND:US1NYQN0027
# SMITHTOWN 2.5 ENE, NY US: 	 GHCND:US1NYSF0069
# RICHMOND 4.1 ESE, IN US: 	 GHCND:US1INWN0018
# COLUMBUS NAS, OH US: 	 GHCND:USW00093834
# SPENCERVILLE 1.1 NNE, OH US: 	 GHCND:US1OHAL0006
# DILLEY 2 S, OR US: 	 GHCND:USC00352325
# ATGLEN 0.2 W, PA US: 	 GHCND:US1PACH0038
# ROBINSON TOWNSHIP 2.2 WNW, PA US: 	 GHCND:US1PAAL0039
# MCKEESPORT, PA US: 	 GHCND:USC00365573
# YORK 4.2 NE, PA US: 	 GHCND:US1PAYR0015
# LENNOX 3.3 NE, SD US: 	 GHCND:US1SDLN0012
# BAYTOWN 1.0 ENE, TX US: 	 GHCND:US1TXHRR075
# TAYLOR, TX US: 	 GHCND:USC00418861
# ALEXANDRIA POTOMAC Y, VA US: 	 GHCND:USC00440097
# GRANDVIEW 1.1 NNE, WA US: 	 GHCND:US1WAYK0013
# YAKIMA 1.0 SSW, WA US: 	 GHCND:US1WAYK0022
# FLAGSTAFF 4.1 NE, AZ US: 	 GHCND:US1AZCN0046
# BERKELEY, CA US: 	 GHCND:USC00040693
# SAN GABRIEL, CA US: 	 GHCND:USC00047775
# SANTA YNEZ AIRPORT, CA US: 	 WBAN:93244
# MERIDEN MARKHAM MUNICIPAL AIRPORT, CT US: 	 WBAN:54788
# MONROE 0.1 SE, CT US: 	 GHCND:US1CTFR0042
# CLARENDON HILLS 0.6 S, IL US: 	 GHCND:US1ILDP0091
# LE CLAIRE, IA US: 	 GHCND:USC00134700
# NORTH SALEM, IN US: 	 COOP:126428
# BEREA COLLEGE, KY US: 	 GHCND:USC00150619
# COOLIDGE, KS US: 	 GHCND:USC00141801
# HARWICH 2.9 NE, MA US: 	 GHCND:US1MABA0023
# ACUSHNET 1.8 SSE, MA US: 	 GHCND:US1MABR0032
# BUCKLAND 1.8 ESE, MA US: 	 GHCND:US1MAFR0017
# EAST WAREHAM, MA US: 	 GHCND:USC00192451
# COLUMBIA 2.3 N, MD US: 	 GHCND:US1MDHW0018
# CLARISSA 0.1 ESE, MN US: 	 GHCND:US1MNTD0009
# FREEPORT 3.3 SE, ME US: 	 GHCND:US1MECM0032
# SHOAL CREEK ESTATES 0.2 SE, MO US: 	 GHCND:US1MONW0004
# BILLINGS 3.7 SSW, MO US: 	 GHCND:US1MOCR0007
# CURRITUCK CO AIRPORT, NC US: 	 WBAN:03737
# NASHUA BOIRE FIELD, NH US: 	 WBAN:54754
# LIVINGSTON TWP 2.0 NNE, NJ US: 	 GHCND:US1NJES0041
# SANDY HOOK, NJ US: 	 GHCND:USC00287865
# WAYNE TWP 0.8 SSW, NJ US: 	 GHCND:US1NJPS0015
# LINDEN 2.2 NW, NJ US: 	 GHCND:US1NJUN0003
# EAST HAMPTON AIRPORT, NY US: 	 WBAN:64761
# OLEAN, NY US: 	 GHCND:USC00306196
# FRESNO 2.2 NNE, OH US: 	 GHCND:US1OHCC0004
# BAY CITY 0.7 NNW, OR US: 	 GHCND:US1ORTL0003
# WILMINGTON, OH US: 	 GHCND:USC00339224
# MALVERN 0.5 NNE, PA US: 	 GHCND:US1PACH0017
# TRENTON NOTTINGHAMWA, NJ US: 	 GHCND:USC00288878
# CARNOT MOON 0.7 ENE, PA US: 	 GHCND:US1PAAL0033
# CUMBERLAND HILL 3.7 E, RI US: 	 GHCND:US1RIPR0035
# WORTHING 2.0 W, SD US: 	 GHCND:US1SDLN0019
# COLUMBIA OWENS DOWNTOWN AIRPORT, SC US: 	 WBAN:53867
# MARSHALL 3.1 E, TX US: 	 GHCND:US1TXHRS017
# BELLINGHAM 4.6 NNW, WA US: 	 GHCND:US1WAWC0065
# RACINE 1.5 NNE, WI US: 	 GHCND:US1WIRC0012
# WOLFVILLE: 	 GHCND:CA008206440
# ANNISTON, AL US: 	 GHCND:USC00010267
# MESA, AZ US: 	 GHCND:USC00025467
# ESCONDIDO 2.5 SSE, CA US: 	 GHCND:US1CASD0010
# SAN FRANCISCO 1.1 SW, CA US: 	 GHCND:US1CASF0004
# FAIRFIELD 1.5 NE, CT US: 	 GHCND:US1CTFR0060
# CRAWFORDVILLE 4.7 SE, FL US: 	 GHCND:US1FLWK0009
# BETTENDORF 1.6 WSW, IA US: 	 GHCND:US1IAST0028
# GLIDDEN 5.9 NNE, IA US: 	 GHCND:US1IACR0006
# KENDALL GREEN, MA US: 	 GHCND:USC00193940
# CAMBRIDGE MUNICIPAL AIRPORT, MN US: 	 WBAN:04909
# HIGH HILL 2.0 N, MO US: 	 GHCND:US1MOMY0006
# MISSOULA 1.6 SE, MT US: 	 GHCND:US1MTMS0024
# DOVER 0.8 E, NH US: 	 GHCND:US1NHST0019
# LEXINGTON 1.5 WNW, NC US: 	 GHCND:US1NCDS0009
# JAFFREY 0.7 NNE, NH US: 	 GHCND:US1NHCH0025
# ROCHESTER, NH US: 	 GHCND:USC00277253
# SOUTHAMPTON TWP 2.4 NW, NJ US: 	 GHCND:US1NJBT0022
# POUGHKEEPSIE PENDELL, NY US: 	 GHCND:USC00306827
# TRUMANSBURG 0.3 NNE, NY US: 	 GHCND:US1NYTM0034
# PORTLAND KGW TV, OR US: 	 GHCND:USC00356749
# ROCHESTER 1 NW, PA US: 	 GHCND:USC00367540
# SPARTANBURG, SC US: 	 WBAN:93804
# COPPERHILL, TN US: 	 GHCND:USC00402024
# NASHVILLE 11.2 SW, TN US: 	 GHCND:US1TNDV0110
# CULPEPER, VA US: 	 GHCND:USC00442155
# ALEXANDRIA 6.9 S, VA US: 	 GHCND:US1VAFX0090
# REEDSBURG, WI US: 	 GHCND:USC00477052
# OREGON 0.8 SSW, WI US: 	 GHCND:US1WIDA0025
# GRAFTON, WV US: 	 GHCND:USC00463627
# MONARCH, WV US: 	 GHCND:USC00466140
# BEAVER CREEK, AZ US: 	 GHCND:USC00020670
# ASPEN PITKIN CO AIRPORT SARDY FIELD, CO US: 	 WBAN:93073
# CLINTON 3.5 N, CT US: 	 GHCND:US1CTMD0015
# TALLAHASSEE 5.7 NNE, FL US: 	 GHCND:US1FLLN0020
# FOLKSTON 9 SW, GA US: 	 GHCND:USC00093465
# NORTH ENGLISH, IA US: 	 GHCND:USC00136076
# BEVERLY SHORES 0.4 NNE, IN US: 	 GHCND:US1INPT0057
# HOPKINSVILLE 0.3 NW, KY US: 	 GHCND:US1KYCH0006
# HOLYOKE, MA US: 	 GHCND:USC00193702
# LYNN 0.8 NE, MA US: 	 GHCND:US1MAES0007
# HOLYOKE 1.0 ENE, MA US: 	 GHCND:US1MAHD0022
# TRURO 0.8 E, MA US: 	 GHCND:US1MABA0052
# WILLIAMSTOWN, MA US: 	 GHCND:USC00199731
# PLEASANT HILL, MO US: 	 GHCND:USC00236748
# RALEIGH 3.8 SSW, NC US: 	 GHCND:US1NCWK0090
# FREMONT 0.6 S, NE US: 	 GHCND:US1NEDD0003
# VINELAND 3.5 NW, NJ US: 	 GHCND:US1NJCD0002
# COEYMANS HOLLOW 2.1 N, NY US: 	 GHCND:US1NYAB0042
# HEMPSTEAD GARDEN CIT, NY US: 	 GHCND:USC00303781
# NEW YORK, NY US: 	 GHCND:USC00305796
# NORTHPORT, NY US: 	 GHCND:USC00306019
# CALDWELL 6 NW, OH US: 	 GHCND:USC00331178
# KELLEYS ISLAND 0.7 WNW, OH US: 	 GHCND:US1OHER0042
# TOLEDO BLADE, OH US: 	 GHCND:USC00338366
# SALEM 2.2 WNW, OR US: 	 GHCND:US1ORPK0035
# MONETTA, SC US: 	 GHCND:USC00385954
# VERMILLION 0.6 SE, SD US: 	 GHCND:US1SDCY0009
# YANKTON 1.7 NNE, SD US: 	 GHCND:US1SDYN0011
# AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US: 	 WBAN:13904
# HERNDON, VA US: 	 GHCND:USC00443929
# DOUSMAN 3.2 SSE, WI US: 	 GHCND:US1WIWK0057
# MANITOWOC, WI US: 	 WBAN:94897
# WHITE SULPHUR SPRINGS, WV US: 	 GHCND:USC00469522
# SACATON, AZ US: 	 GHCND:USC00027370
# MOUNT DIABLO STATE P, CA US: 	 COOP:045916
# DE WITT 0.6 N, AR US: 	 GHCND:US1ARAR0001
# FORT MORGAN 3.7 NNW, CO US: 	 GHCND:US1COMR0042
# GROVETOWN 2.0 SSW, GA US: 	 GHCND:US1GACU0011
# ALBION, IL US: 	 GHCND:USC00110055
# BREWSTER 1.4 W, MA US: 	 GHCND:US1MABA0080
# BARDSTOWN, KY US: 	 GHCND:USC00150389
# BUCKSPORT 3.3 NNW, ME US: 	 GHCND:US1MEHN0042
# BRIDGTON 2.9 NNE, ME US: 	 GHCND:US1MECM0012
# NORTH MANKATO 1.3 ESE, MN US: 	 GHCND:US1MNNC0007
# JEFFERSON BARRACKS, MO US: 	 GHCND:USC00234272
# SALEM 1.1 NNE, MO US: 	 GHCND:US1MODT0012
# NEW BRUNSWICK, NJ US: 	 GHCND:USC00286062
# CENTERPORT 0.9 SW, NY US: 	 GHCND:US1NYSF0061
# REMSENBURG SPEONK 0.9 NE, NY US: 	 GHCND:US1NYSF0080
# SCHENECTADY 5.6 SSW, NY US: 	 GHCND:US1NYAB0006
# ELMSFORD 0.8 SSW, NY US: 	 GHCND:US1NYWC0019
# GALION 1.8 SE, OH US: 	 GHCND:US1OHMW0005
# PORTLAND 7 SW, OR US: 	 GHCND:US1ORMT0015
# WILLOW GROVE 0.8 ENE, PA US: 	 GHCND:US1PAMT0063
# FORTY FORT 0.4 NNE, PA US: 	 GHCND:US1PALZ0024
# UPPER DARBY, PA US: 	 GHCND:USC00369074
# LIMERICK 1.0 W, PA US: 	 GHCND:US1PAMT0086
# BROWERS LOCK, PA US: 	 GHCND:USC00361017
# SOUDERTON 0.6 NNW, PA US: 	 GHCND:US1PAMT0037
# ARANSAS PASS 2, TX US: 	 GHCND:USC00410302
# EAGLE LAKE, TX US: 	 COOP:412675
# NEWFANE 0.8 NE, VT US: 	 GHCND:US1VTWH0002
# QUEBEC 2, CA: 	 GHCND:CA007016281
# RIVERSIDE 0.0 W, CA US: 	 GHCND:US1CARV0054
# TURLOCK NUMBER 2, CA US: 	 GHCND:USC00049073
# GOLDEN 0.7 SW, CO US: 	 GHCND:US1COJF0022
# FORT PIERCE ARC, FL US: 	 GHCND:USC00083209
# STERLING GEORGIA, GA US: 	 GHCND:USR0000GSTE
# GARY 4.8 ENE, IN US: 	 GHCND:US1INLK0063
# BOWLING GREEN 3.7 S, KY US: 	 GHCND:US1KYWR0025
# NEW BEDFORD COOP, MA US: 	 GHCND:USC00195246
# FORT GEORGE G MEADE, MD US: 	 GHCND:USC00183230
# COLON 3.5 SE, MI US: 	 GHCND:US1MIBH0006
# CAMDEN 0.1 WSW, MI US: 	 GHCND:US1MIHL0003
# HUTCHINSON 1.5 SSE, MN US: 	 GHCND:US1MNMC0010
# REED CITY, MI US: 	 GHCND:USC00206922
# ELSAH PRINCIPIA COL, IL US: 	 GHCND:USC00112800
# BISMARCK 0.6 NNW, ND US: 	 GHCND:US1NDBH0036
# HAVERHILL 3.6 WNW, MA US: 	 GHCND:US1MAES0003
# KEENE 3 S, ND US: 	 GHCND:USC00324571
# SOUTH BRUNSWICK TWP 2.4 WSW, NJ US: 	 GHCND:US1NJMD0091
# FORT PLAIN 0.2 SE, NY US: 	 GHCND:US1NYMG0001
# MORAVIA 2.5 ESE, NY US: 	 GHCND:US1NYCY0013
# HONEOYE FALLS 1.7 NE, NY US: 	 GHCND:US1NYMR0055
# ALTOONA 1.0 NNE, PA US: 	 GHCND:US1PABL0010
# LEBANON 5.2 SSE, OR US: 	 GHCND:US1ORLN0034
# CHAMBERSBURG 0.9 SE, PA US: 	 GHCND:US1PAFN0003
# MORGANTOWN HART FIELD, WV US: 	 WBAN:13736
# CALGARY 2.0 NW BRBC, CA: 	 GHCND:CA1AB000012
# COMOX 1.0 E, CA: 	 GHCND:CA1BC000056
# HATLEY, CA: 	 GHCND:CA007023005
# EASTEND 2, CA: 	 GHCND:CA004032323
# SAN DIEGO 9.5 NNW, CA US: 	 GHCND:US1CASD0060
# PUEBLO 13.0 SSW, CO US: 	 GHCND:US1COPU0078
# MADISON CENTER 1.4 WNW, CT US: 	 GHCND:US1CTNH0033
# EMMETSBURG, IA US: 	 GHCND:USC00132689
# ST. PETERSBURG 4.5 NW, FL US: 	 GHCND:US1FLPN0060
# NORTH LIBERTY 1.0 ENE, IA US: 	 GHCND:US1IAJH0008
# WAUKEGAN, IL US: 	 GHCND:USC00119029
# GARY, IN US: 	 WBAN:04807
# TOPEKA, KS US: 	 NEXRAD:KTWX
# LEXINGTON 0.3 NE, MA US: 	 GHCND:US1MAMD0096
# WALPOLE 1 SSE, MA US: 	 GHCND:USC00198760
# DORCHESTER, MA US: 	 GHCND:USC00191950
# WELLESLEY 0.1 W, MA US: 	 GHCND:US1MANF0035
# CHESAPEAKE BEACH 0.1 SSE, MD US: 	 GHCND:US1MDCV0018
# GREENSBORO 1.4 ENE, MD US: 	 GHCND:US1MDCL0009
# KENNEBUNK 1.8 WNW, ME US: 	 GHCND:US1MEYK0005
# LEXINGTON 0.0 ENE, MO US: 	 GHCND:US1MOLF0013
# ATLANTIC CITY MARINA, NJ US: 	 WBAN:13724
# HIGHTSTOWN PUMP STATION, NJ US: 	 GHCND:USC00283956
# GLEN ROCK 0.4 WNW, NJ US: 	 GHCND:US1NJBG0037
# MAPLEWOOD TWP 0.9 SE, NJ US: 	 GHCND:US1NJES0018
# GORHAM 0.8 S, NY US: 	 GHCND:US1NYON0011
# MASSAPEQUA PARK 1.2 N, NY US: 	 GHCND:US1NYNS0046
# PORT WASHINGTON 0.8 N, NY US: 	 GHCND:US1NYNS0027
# MARCELLUS 1.6 E, NY US: 	 GHCND:US1NYOG0031
# FREEHOLD 3.4 E, NY US: 	 GHCND:US1NYGR0006
# AKRON, OH US: 	 GHCND:USC00330061
# HAMILTON 2, OH US: 	 GHCND:USC00333482
# PAINESVILLE HIGHWAY DE, OH US: 	 GHCND:USC00336384
# SAPULPA 1 W, OK US: 	 GHCND:USC00347921
# NORMAN 2.8 NNE, OK US: 	 GHCND:US1OKCV0133
# INGRAM, PA US: 	 GHCND:USC00364258
# EMSWORTH L D OHIO RV, PA US: 	 GHCND:USC00362574
# TRENTON WEATHER SERVICE OFFICE CITY, NJ US: 	 GHCND:USW00014773
# TOWANDA 4.6 NNE, PA US: 	 GHCND:US1PABF0006
# PROVIDENCE 3.0 ENE, RI US: 	 GHCND:US1RIPR0011
# WOODSVILLE, NH US: 	 GHCND:USC00279950
# WAUSAU 1.7 ENE, WI US: 	 GHCND:US1WIMT0004
# WASHINGTON DAM 19, OH US: 	 GHCND:USC00469309
# CAMROSE, CA: 	 GHCND:CA003011240
# BOWMANVILLE MOSTERT, CA: 	 GHCND:CA006150830
# LEAMINGTON 6.4 SE AGRIS, CA: 	 GHCND:CA1ON000442
# FARMINGTON 0.4 NNE, AR US: 	 GHCND:US1ARWS0017
# PAONIA .55 ESE, CO US: 	 GHCND:US1CODL0009
# PENSACOLA 1.9 NE, FL US: 	 GHCND:US1FLES0026
# PLANT CITY, FL US: 	 GHCND:USC00087205
# INDEPENDENCE 0.3 NNE, IA US: 	 GHCND:US1IABC0003
# SAINT MEINRAD, IN US: 	 GHCND:USC00127724
# BYFIELD 1.8 ESE, MA US: 	 GHCND:US1MAES0014
# WATERVILLE 2.5 NNE, ME US: 	 GHCND:US1MEKB0020
# PHILLIPSBURG, MO US: 	 GHCND:USC00236669
# GARDINER, MT US: 	 GHCND:USC00243378
# WEARE 3.9 SSE, NH US: 	 GHCND:US1NHHL0085
# BLOOMFIELD 1.7 S, NJ US: 	 GHCND:US1NJES0020
# LOWER TWP 2.2 NE, NJ US: 	 GHCND:US1NJCM0004
# ELIZABETH, NJ US: 	 GHCND:USC00282644
# MONTCLAIR 2.2 NNE, NJ US: 	 GHCND:US1NJES0015
# SOUTHOLD 0.7 NNE, NY US: 	 GHCND:US1NYSF0042
# WATERFORD 0.4 NNW, NY US: 	 GHCND:US1NYSR0013
# PIEDMONT LAKE, OH US: 	 GHCND:USC00336616
# FAIRVIEW PARK 1.4 NE, OH US: 	 GHCND:US1OHCY0001
# LEESVILLE LAKE, OH US: 	 GHCND:USC00334473
# BUSTLETON, PA US: 	 GHCND:USC00361117
# TILLAMOOK 6 SE, OR US: 	 GHCND:USC00358498
# GROVE CITY, PA US: 	 GHCND:USC00363542
# COLDSTREAM, CA: 	 GHCND:CA006141763
# HAMILTON, CA: 	 GHCND:CA008300438
# ILDERTON BEAR CREEK, CA: 	 GHCND:CA006143722
# SUGAR CITY 2.3 S, CO US: 	 GHCND:US1COCR0015
# NEW SMYRNA BEACH MUNICIPAL AIRPORT, FL US: 	 WBAN:92808
# ST MARKS 5 SSE, FL US: 	 GHCND:USC00087867
# MACON 1.7 WSW, GA US: 	 GHCND:US1GABB0001
# NEW HAMPTON 0.3 NNW, IA US: 	 GHCND:US1IACW0003
# KEOKUK MUNICIPAL AIRPORT, IA US: 	 WBAN:04921
# WASHTA, IA US: 	 GHCND:USC00138693
# PAXTON 0.3 NNW, IL US: 	 GHCND:US1ILFD0005
# OSKALOOSA, IA US: 	 GHCND:USC00136327
# WINNETKA 0.8 ESE, IL US: 	 GHCND:US1ILCK0193
# HOLLAND, IN US: 	 GHCND:USC00124023
# GOSHEN 1.8 S, IN US: 	 GHCND:US1INEL0012
# TERRE HAUTE 4.0 S, IN US: 	 GHCND:US1INVG0005
# HESSTON 0.6 SW, KS US: 	 GHCND:US1KSHV0026
# HAYS 2 S, KS US: 	 GHCND:USC00143537
# ATTLEBORO 0.9 ENE, MA US: 	 GHCND:US1MABR0023
# PERRY HALL 0.9 E, MD US: 	 GHCND:US1MDBL0019
# DEALE 3.0 S, MD US: 	 GHCND:US1MDAA0044
# SPARKILL, NY US: 	 GHCND:USC00308072
# BUCKEYE LAKE 1 N, OH US: 	 GHCND:USC00331057
# PAULDING, OH US: 	 GHCND:USC00336465
# SUGAR GROVE 4.5 ENE, OH US: 	 GHCND:US1OHHK0004
# RINGGOLD, OH US: 	 GHCND:USC00337107
# MONMOUTH, OR US: 	 GHCND:USC00355689
# PHILADELPHIA AIRPORT SNOW, PA US: 	 GHCND:USC00366880
# MUNCY 0.5 SSE, PA US: 	 GHCND:US1PALY0001
# EAST NANTMEAL 1.0 SSW, PA US: 	 GHCND:US1PACH0029
# HARRISVILLE 0.6 WNW, RI US: 	 GHCND:US1RIPR0012
# NEWPORT 0.9 N, RI US: 	 GHCND:US1RINW0012
# FLANDREAU, SD US: 	 GHCND:USC00392984
# DELL RAPIDS 0.5 NW, SD US: 	 GHCND:US1SDMH0022
# GEORGETOWN, TX US: 	 GHCND:USC00413506
# BERRYVILLE, VA US: 	 GHCND:USC00440670
# HASKELL 0.5 NW, TX US: 	 GHCND:US1TXHSK004
# LADYSMITH 3 W, WI US: 	 GHCND:USC00474391
# NILESTOWN, CA: 	 GHCND:CA00614N003
# OTTAWA, CA: 	 GHCND:CA006105887
# MORIN HEIGHTS, CA: 	 GHCND:CA007035360
# PRIMROSE FARM, AL US: 	 GHCND:USC00016684
# SUPERIOR SMELTER, AZ US: 	 GHCND:USC00028351
# GRAND JUNCTION 2.3 N, CO US: 	 GHCND:US1COME0108
# WILMINGTON 5.6 N, DE US: 	 GHCND:US1DENC0040
# ABERDEEN 1.1 NNW, FL US: 	 GHCND:US1FLPB0059
# ZEPHYRHILLS 0.9 ENE, FL US: 	 GHCND:US1FLPS0008
# OGDEN, IA US: 	 GHCND:USC00136205
# BLOOMINGTON 1.9 W, IL US: 	 GHCND:US1ILMCL003
# OAKLAND, IL US: 	 GHCND:USC00116329
# WALNUT 5.3 ENE, IL US: 	 GHCND:US1ILBU0011
# NOBLESVILLE RIVER, IN US: 	 GHCND:USC00126338
# FRAMINGHAM 1.7 E, MA US: 	 GHCND:US1MAMD0107
# PRINCETON, MA US: 	 GHCND:USC00196644
# WESTON, MA US: 	 GHCND:USC00199360
# ANNAPOLIS POLICE BAR, MD US: 	 GHCND:USC00180193
# MUNSING LAKESHORE, US: 	 WBAN:54813
# PORT HURON ST CLAIR CO INTERNATIONAL AIRPORT, MI US: 	 WBAN:04888
# WILLARD 2.6 W, MO US: 	 GHCND:US1MOGR0081
# JAMESTOWN STATE HOSPITAL, ND US: 	 GHCND:USC00324418
# PLATTSMOUTH 0.2 NNE, NE US: 	 GHCND:US1NECA0003
# STRAFFORD 1.3 SSE, NH US: 	 GHCND:US1NHST0018
# RUBY 0.5 NE, NY US: 	 GHCND:US1NYUL0004
# BROCKPORT 1.5 ENE, NY US: 	 GHCND:US1NYMR0029
# MINEOLA, NY US: 	 GHCND:USC00305377
# HEMPSTEAD MALVERNE, NY US: 	 GHCND:USC00303786
# OSSINING SING SING, NY US: 	 GHCND:USC00306301
# DAYTON 6.7 NNW, OH US: 	 GHCND:US1OHMY0025
# WORTHINGTON 5 N, OH US: 	 GHCND:USC00339332
# CINCINNATI 5.3 NE, OH US: 	 GHCND:US1OHHM0022
# WYOMING 1.2 NW, OH US: 	 GHCND:US1OHHM0003
# BURGETTSTOWN 2 W, PA US: 	 GHCND:USC00361105
# LEXINGTON 5.3 W, VA US: 	 GHCND:US1VARK0005
# ELLSWORTH 1.4 S, WI US: 	 GHCND:US1WIPC0022
# EVANSVILLE 0.4 E, WI US: 	 GHCND:US1WIRK0006
# ROCK CAVE 2 NE, WV US: 	 GHCND:USC00467649
# CALEDON VILLAGE, CA: 	 GHCND:CA006151082
# KITCHENER CITY ENG 1, CA: 	 GHCND:CA006144240
# OWEN SOUND 1.4 SSW GSCA, CA: 	 GHCND:CA1ON000502
# FAIRHOPE 1.4 W, AL US: 	 GHCND:US1ALBW0042
# WATERFORD 2.2 N, CT US: 	 GHCND:US1CTNL0017
# AMES MUNICIPAL AIRPORT, IA US: 	 WBAN:94989
# WINTHROP 5.6 NNE, IA US: 	 GHCND:US1IABC0009
# BLOOMINGTON 6.1 NE, IN US: 	 GHCND:US1INMN0016
# MARION DISPOSAL PLAN, IN US: 	 GHCND:USC00125342
# WILLOW BRANCH 0.2 NNW, IN US: 	 GHCND:US1INHN0019
# LINDSBORG 0.3 E, KS US: 	 GHCND:US1KSMP0008
# MCPHERSON 0.9 NE, KS US: 	 GHCND:US1KSMP0048
# PITTSBURG, KS US: 	 GHCND:USC00146414
# ORLEANS 1.1 E, MA US: 	 GHCND:US1MABA0012
# MCMILLAN, MI US: 	 GHCND:USC00205274
# MAPLEWOOD 2.7 SE, MN US: 	 GHCND:US1MNRM0020
# CHAPEL HILL 2 W, NC US: 	 GHCND:USC00311677
# CARRINGTON 0.3 W, ND US: 	 GHCND:US1NDFS0009
# FAIRBURY 0.6 N, NE US: 	 GHCND:US1NEJF0004
# STRATFORD 0.5 WNW, NJ US: 	 GHCND:US1NJCN0015
# NORTH COHOCTON SOIL CONSERVATION SERVICE, NY US: 	 GHCND:USC00305917
# POUGHKEEPSIE 4.7 ESE, NY US: 	 GHCND:US1NYDT0002
# JAMESTOWN WATERWORKS, NY US: 	 GHCND:USC00304208
# OXFORD 0.4 W, PA US: 	 GHCND:US1PACH0033
# MOUNT VERNON 0.5 NE, VA US: 	 GHCND:US1VAFX0031
# VIRGINIA BEACH 3.8 SSE, VA US: 	 GHCND:US1VAVBC019
# BRUSSELS 0.4 ESE MVCA, CA: 	 GHCND:CA1ON000149
# COBDEN ONTARIO HYDRO, CA: 	 GHCND:CA006101675
# HEALDSBURG 0.6 W, CA US: 	 GHCND:US1CASN0108
# TEXARKANA 10.8 E, AR US: 	 GHCND:US1ARML0006
# NEPTUNE BEACH 0.5 NNW, FL US: 	 GHCND:US1FLDV0013
# GAINESVILLE 5.0 SSW, FL US: 	 GHCND:US1FLAL0058
# TALLAHASSEE 9.6 N, FL US: 	 GHCND:US1FLLN0034
# ATHENS 1.0 N, IL US: 	 GHCND:US1ILME0009
# WALTONVILLE, IL US: 	 GHCND:USC00118932
# FRANKFORT 7.9 WSW, IN US: 	 GHCND:US1INCL0010
# HOBART 1.0 E, IN US: 	 GHCND:US1INLK0088
# MUNCIE 1.2 SE, IN US: 	 GHCND:US1INDL0032
# WORTHINGTON, IN US: 	 GHCND:USC00129792
# WOODBINE 0.6 NNW, KS US: 	 GHCND:US1KSDK0021
# AMHERST, MA US: 	 GHCND:USC00190120
# BEVERLY MUNICIPAL AIRPORT, MA US: 	 WBAN:54733
# SALEM B, MA US: 	 GHCND:USC00197122
# PLAINWELL DAM, MI US: 	 GHCND:USC00206630
# MCCLELLANVILLE 7 NE, SC US: 	 WBAN:03728
# LEBANON 0.6 N, MO US: 	 GHCND:US1MOLD0023
# ESSEX FELLS SERV BUILDING, NJ US: 	 GHCND:USC00282773
# HIGHLAND PARK 0.5 E, NJ US: 	 GHCND:US1NJMD0074
# MILLBROOK, NY US: 	 GHCND:USC00305334
# WILLETS POINT: 	 GHCND:USC00309466
# MILLER PLACE 0.5 ENE, NY US: 	 GHCND:US1NYSF0037
# CLINTON CORNERS, NY US: 	 COOP:301559
# FREDERICKTOWN 4.0 NNW, OH US: 	 GHCND:US1OHKN0004
# WAUSEON 0.2 SE, OH US: 	 GHCND:US1OHFL0002
# MIFFLIN, PA US: 	 GHCND:USC00365720
# RIDGWAY, PA US: 	 GHCND:USC00367477
# BLOCK ISLAND, RI US: 	 GHCND:USW00014799
# FREE UNION, VA US: 	 GHCND:USC00443213
# TRACYTON 2.3 WSW, WA US: 	 GHCND:US1WAKP0007
# WINNIPEG 5.3 SW, CA: 	 GHCND:CA1MB000200
# FRANKFORD MOE, CA: 	 GHCND:CA006152555
# PAKENHAM 7.8 NNW, CA: 	 GHCND:CA1ON000208
# MONTEREY 1.1 SSW, CA US: 	 GHCND:US1CAMT0030
# DENVER 3.6 E, CO US: 	 GHCND:US1CODN0110
# CAPE CORAL 5.1 WSW, FL US: 	 GHCND:US1FLLE0013
# BARTLETT 5 E, IA US: 	 GHCND:USC00130493
# MARSHALL, IL US: 	 GHCND:USC00115380
# NORTHBROOK UNDER LAB, IL US: 	 GHCND:USC00116227
# RIVERTON, IN US: 	 GHCND:USC00127442
# PENDLETON REFORMATOR, IN US: 	 GHCND:USC00126808
# NEWTON, MA US: 	 GHCND:USC00195317
# CUMMINGTON HILL, MA US: 	 GHCND:USC00191774
# PELHAM, MA US: 	 GHCND:USC00196251
# LA PLATA 1.2 WSW, MD US: 	 GHCND:US1MDCH0010
# BETHESDA, MD US: 	 GHCND:USC00180795
# YPSILANTI 1.1 ENE, MI US: 	 GHCND:US1MIWS0018
# DASSEL 0.4 S, MN US: 	 GHCND:US1MNMK0011
# HARWOOD 1.7 NNW, ND US: 	 GHCND:US1NDCS0039
# KINDRED, ND US: 	 COOP:324756
# LITTLE EGG HARBOR TWP 5.4 N, NJ US: 	 GHCND:US1NJOC0036
# BOONTON 1 SE, NJ US: 	 GHCND:USC00280907
# PLEASANTVILLE, NY US: 	 GHCND:USC00306674
# BLUE POINT 0.4 E, NY US: 	 GHCND:US1NYSF0060
# MELROSE 1 NE, NY US: 	 GHCND:USC00305248
# ROSEMOUNT 0.3 W, OH US: 	 GHCND:US1OHSC0004
# MUSKOGEE 1.2 NE, OK US: 	 GHCND:US1OKMK0005
# OKMULGEE WATER WORKS, OK US: 	 GHCND:USC00346670
# OKLAHOMA CITY 6.7 NW, OK US: 	 GHCND:US1OKOK0070
# OAKMONT 0.8 N, PA US: 	 GHCND:US1PAAL0041
# READING 3.5 NNW, PA US: 	 GHCND:US1PABR0017
# DREXEL UNIVERSITY, PA US: 	 GHCND:USC00366879
# MCMURRAY 0.2 NE, PA US: 	 GHCND:US1PAWS0005
# PRIMOS, PA US: 	 GHCND:USC00367166
# KINGSTON 2.4 SW, RI US: 	 GHCND:US1RIWS0037
# FORT WORTH NAS, TX US: 	 WBAN:13911
# BROWNSVILLE 1.9 ESE, TX US: 	 GHCND:US1TXCMR023
# WELLSBURG WATER TREATMENT P, WV US: 	 GHCND:USC00469368
# PUTNAM 0.8 SW, CT US: 	 GHCND:US1CTWN0020
# STIRLING, CA: 	 GHCND:CA006158052
# METCALFE, CA: 	 GHCND:CA006145064
# GODERICH LIGHTHOUSE, CA: 	 GHCND:CA006122848
# AURORA BUCKLEY FIELD ANGB, CO US: 	 WBAN:23036
# FORT COLLINS 5.0 N, CO US: 	 GHCND:US1COLR0019
# FORT CARSON COLORADO, CO US: 	 GHCND:USR0000CFTC
# WOODBURY, CT US: 	 GHCND:USC00069775
# MARION 1.9 W, IL US: 	 GHCND:US1ILWM0005
# ANDERSON 0.2 WNW, IN US: 	 GHCND:US1INMD0027
# HORTON, KS US: 	 GHCND:USC00143810
# THREE RIVERS MUNICIPAL DR HAINES AIRPORT, MI US: 	 WBAN:54850
# INDEPENDENCE 1.2 SSE, MO US: 	 GHCND:US1MOJC0024
# LIBBY, MT US: 	 GHCND:USC00245000
# KEENE 2.5 NNW, NH US: 	 GHCND:US1NHCH0024
# WEST POINT, NY US: 	 GHCND:USC00309292
# WEST ISLIP 0.6 SW, NY US: 	 GHCND:US1NYSF0065
# LYNDONVILLE, NY US: 	 GHCND:USC00304939
# SILVER SPRINGS 3 N, NY US: 	 GHCND:USC00307749
# WESTLAKE 0.5 SSW, OH US: 	 GHCND:US1OHCY0039
# WOOSTER 4.8 SW, OH US: 	 GHCND:US1OHWN0003
# SOUTH PARK TOWNSHIP 0.2 NW, PA US: 	 GHCND:US1PAAL0023
# SOUTHAMPTON, PA US: 	 GHCND:USC00368263
# DALLAS 2.7 WNW, TX US: 	 GHCND:US1TXDA0053
# NAIN, CA: 	 GHCND:CA008502799
# SUMMERLAND, CA: 	 GHCND:CA001127798
# GILMOUR, CA: 	 GHCND:CA006162787
# OSHAWA WPCP, CA: 	 GHCND:CA006155878
# FLORENCE, CO US: 	 GHCND:USC00052955
# NEWINGTON 1.9 SSW, CT US: 	 GHCND:US1CTHR0065
# MANSFIELD CENTER 1.9 SW, CT US: 	 GHCND:US1CTTL0004
# DELAWARE CITY REEDY, DE US: 	 GHCND:USC00072625
# SIGOURNEY, IA US: 	 GHCND:USC00137678
# MARENGO 0.7 NNW, IL US: 	 GHCND:US1ILMCH087
# OAKLEY 0.3 NE, KS US: 	 GHCND:US1KSLG0010
# EAST SANGERVILLE, ME US: 	 GHCND:USC00172440
# PORT TOBACCO VILLAGE 1.0 S, MD US: 	 GHCND:US1MDCH0011
# WEBBER DAM, MI US: 	 GHCND:USC00208746
# LA SALLE 2.0 S, CA: 	 GHCND:CA1ON000655
# ROCKAWAY BEACH 1.3 NNW, MO US: 	 GHCND:US1MOTY0008
# CLARKSVILLE LOCK AND DAM 24, MO US: 	 GHCND:USC00231640
# FORTINE 1 N, MT US: 	 GHCND:USC00243139
# TAYLORSVILLE, NC US: 	 GHCND:USC00318519
# CHAUTAUQUA, NY US: 	 GHCND:USC00301395
# ASHVILLE 6.3 E, OH US: 	 GHCND:US1OHPC0001
# CELINA 1.8 ENE, OH US: 	 GHCND:US1OHMC0001
# TULSA INTERNATIONAL AIRPORT, OK US: 	 WBAN:13968
# STROUDSBURG, PA US: 	 GHCND:USC00368601
# TIMMONSVILLE 0.5 SSW, SC US: 	 GHCND:US1SCFL0001
# LYNCHBURG 1.3 SSW, VA US: 	 GHCND:US1VABD0019
# COURTENAY SANDWICK, CA: 	 GHCND:CA001021994
# TAPLEY, CA: 	 GHCND:CA006168525
# ATHENS, CA: 	 GHCND:CA006100375
# KINGSTON BEVERLEY ST, CA: 	 GHCND:CA006104147
# ST SEBASTIEN CDA FE, CA: 	 GHCND:CA007027730
# CALICO ROCK 1.6 E, AR US: 	 GHCND:US1ARIZ0002
# MECCA FIRE STATION, CA US: 	 GHCND:USC00045502
# SANTA MONICA, CA US: 	 GHCND:USC00047950
# LOS ALAMITOS, CA US: 	 GHCND:USW00093106
# LYONS 0.2 NE, CO US: 	 GHCND:US1COBO0237
# DENVER 11.2 SW, CO US: 	 GHCND:US1COJF0214
# STEVENSON DAM, CT US: 	 GHCND:USC00068065
# GULFPORT 0.6 SSE, FL US: 	 GHCND:US1FLPN0087
# STAMFORD 4.2 S, CT US: 	 GHCND:US1CTFR0039
# ORLANDO 2.9 NNE, FL US: 	 GHCND:US1FLOR0028
# LOUISVILLE 4.4 N, IL US: 	 GHCND:US1ILCY0002
# ROCKVILLE, IN US: 	 GHCND:USC00127522
# WINTERPORT 2.9 N, ME US: 	 GHCND:US1MEWL0008
# COROLLA 11.7 NNW, NC US: 	 GHCND:US1NCCC0001
# TUCKERTON 2 NE, NJ US: 	 GHCND:USC00288899
# DELMAR 0.8 ESE, NY US: 	 GHCND:US1NYAB0029
# HIRAM 0.4 N, OH US: 	 GHCND:US1OHPT0009
# NORWICH 1 E, OH US: 	 GHCND:USC00336136
# SCRANTON, PA US: 	 GHCND:USC00367902
# MEMPHIS 5.5 ENE, TN US: 	 GHCND:US1TNSH0011
# ROUGEMONT, CA: 	 GHCND:CA007026700
# MAMMOTH SPRING, AR US: 	 GHCND:USC00034572
# ARTESIA 0.5 W, CA US: 	 GHCND:US1CALA0068
# NORTHRIDGE CAL STATE, CA US: 	 GHCND:USC00046263
# SANTA CLARA 3.1 ESE, CA US: 	 GHCND:US1CASC0037
# LUMBER CITY, GA US: 	 GHCND:USC00095386
# TATE, GA US: 	 GHCND:USC00098575
# LA FONTAINE 1.1 NW, IN US: 	 GHCND:US1INWB0010
# MONROE 5.5 ENE, LA US: 	 GHCND:US1LAOC0023
# NANTUCKET SHOALS AFS: 	 GHCND:USW00014658
# PERRY POINT, MD US: 	 GHCND:USC00186980
# LAKE CITY 4.4 NNW, MN US: 	 GHCND:US1MNGH0027
# SHAKOPEE 2.6 W, MN US: 	 GHCND:US1MNSC0033
# ST. CHARLES 2.3 NE, MO US: 	 GHCND:US1MOSS0027
# SUPERIOR, MT US: 	 GHCND:USW00024159
# BUCK FOREST, NC US: 	 GHCND:USC00311174
# MINOT, ND US: 	 COOP:325980
# POINT PLEASANT BEACH 0.5 SW, NJ US: 	 GHCND:US1NJOC0013
# VERONA TWP 0.8 W, NJ US: 	 GHCND:US1NJES0040
# GREENE 0.3 NE, NY US: 	 GHCND:US1NYCN0003
# RUSSELLS POINT LAKEV, OH US: 	 GHCND:USC00337333
# LANCASTER, OH US: 	 GHCND:USC00334403
# MONTROSE 0.4 ENE, PA US: 	 GHCND:US1PASS0022
# CHARLESTOWN 1.1 ENE, RI US: 	 GHCND:US1RIWS0026
# HURLEY 0.2 S, SD US: 	 GHCND:US1SDTR0009
# RICHMOND CHIMBORAZO PARK, VA US: 	 GHCND:USW00013780
# WATERTOWN, WI US: 	 GHCND:USC00478919
# GRAFTON 0.2 SE, WI US: 	 GHCND:US1WIOZ0016
# PHOENIX 7.1 WNW, AZ US: 	 GHCND:US1AZMR0101
# ...
# LANGENBURG, CA: 	 GHCND:CA004014145
# GULL LAKE, CA: 	 GHCND:CA004023053
# STRANRAER, CA: 	 GHCND:CA004047798
# JADACAQUIVA, VE: 	 GHCND:VE000000117
# ALMIRANTE PADILLA, CO: 	 GHCND:COM00080035
# SIMON BOLIVAR, CO: 	 GHCND:COM00080009
# TOCUYO DE LA COSTA, VE: 	 GHCND:VE000000396
# PUYO, EC: 	 GHCND:ECM00084179
# LA DESIRADE: 	 GHCND:GPM00078890
# TALA, MX: 	 GHCND:MXN00014351
# EJIDO DOCTOR OVIEDO MOTA, MX: 	 GHCND:MXN00002087
# DURANGO DGE, MX: 	 GHCND:MXN00010092
# PONCITLAN, MX: 	 GHCND:MXN00014111
# LA HAMACA, MX: 	 GHCND:MXN00020206
# COCHIBAMPO, MX: 	 GHCND:MXN00026234
# SHAGELUK, AK US: 	 GHCND:USC00508379
# QUINCY, CA US: 	 GHCND:USC00047195
# GYPSUM 3.0 SE, CO US: 	 GHCND:US1COEG0001
# VERNON, FL US: 	 GHCND:USC00089206
# BOSTETTER, ID US: 	 GHCND:USC00101090
# KB9UUO NEW CHICAGO 0.6 SSE, IN US: 	 GHCND:US1INLK0058
# CORBIN 8 W, KY US: 	 GHCND:USC00151808
# SCOTTSVILLE 9.2 ESE, KY US: 	 GHCND:US1KYAL0004
# HAMPSTEAD 1.9 S, NC US: 	 GHCND:US1NCPD0011
# CHIMNEY ROCK, NC US: 	 GHCND:USC00311760
# POWERS LAKE 1 N, ND US: 	 GHCND:USC00327281
# XENIA 2.1 NNE, OH US: 	 GHCND:US1OHGR0013
# HAWORTH 0.2 NNW, OK US: 	 GHCND:US1OKMN0006
# ASHLAND 2.9 SE, OR US: 	 GHCND:US1ORJC0042
# TYGH VALLEY, OR US: 	 COOP:358717
# CLOSED, TX US: 	 GHCND:US1TXVV0004
# ARMSTRONG, TX US: 	 GHCND:USC00410342
# LANCASTER AIRPORT, TX US: 	 WBAN:53975
# CANYONLANDS THE NECK, UT US: 	 GHCND:USC00421163
# FORT MACLEOD STAND OFF, CA: 	 GHCND:CA003032690
# BLAIRMORE HQTS RANGER STATION, CA: 	 GHCND:CA0030507AC
# GARDEN RIVER, CA: 	 GHCND:CA00307KPFP
# 100 MILE HOUSE, CA: 	 GHCND:CA001165791
# NEW DENVER, CA: 	 GHCND:CA001145460
# HODGSON, CA: 	 GHCND:CA005031300
# TRURO NSAC, CA: 	 GHCND:CA008206000
# BLIND RIVER HYDRO CENTRE, CA: 	 GHCND:CA006050805
# LIONS HEAD, CA: 	 GHCND:CA006114437
# ST LIN DES LAURENTIDES, CA: 	 GHCND:CA007017480
# STORNOWAY, CA: 	 GHCND:CA004017797
# FORT QU APPELLE, CA: 	 GHCND:CA004012600
# CARMACKS, CA: 	 GHCND:CA002100300
# CASA BLANCA LA HABANA: 	 GHCND:CUM00078325
# KINGSTON, JM: 	 GHCND:JMW00011704
# SAN JERONIMITO, MX: 	 GHCND:MXN00012121
# COPPER CENTER, AK US: 	 GHCND:USC00502156
# SOLDOTNA 6 W, AK US: 	 GHCND:USC00508613
# BEAR CREEK LAKE, AR US: 	 GHCND:USC00030496
# FORT BRAGG, CA US: 	 GHCND:USC00043164
# MARIPOSA, CA US: 	 GHCND:USC00045346
# OAKHURST 1.4 SSE, CA US: 	 GHCND:US1CAMA0012
# ORICK 5.9 SSW, CA US: 	 GHCND:US1CAHM0003
# FLAGLER .06 WNW, CO US: 	 GHCND:US1COKC0085
# PAGOSA SPRINGS 1.6 SSW, CO US: 	 GHCND:US1COAU0026
# LANAI CITY 672, HI US: 	 GHCND:USC00515286
# ELK POINT, SD US: 	 GHCND:USC00392618
# NEW WINDSOR 2.0 N, IL US: 	 GHCND:US1ILHY0006
# JACOB 0.9 SE, IL US: 	 GHCND:US1ILJK0021
# VINCENNES 4 E, IN US: 	 GHCND:USC00129112
# EL DORADO, KS US: 	 GHCND:USC00142401
# LIMESTONE LORING AFB, ME US: 	 GHCND:USW00014623
# BREEZY POINT 1.6 ENE, MN US: 	 GHCND:US1MNCW0004
# BUFORD, ND US: 	 GHCND:USC00321144
# EAST LAS VEGAS 1.3 NNW, NV US: 	 GHCND:US1NVCK0010
# PAINESVILLE 3.8 SSW, OH US: 	 GHCND:US1OHLK0001
# MEDIX RUN, PA US: 	 GHCND:USC00365627
# GREENWOOD RESERVOIR, PA US: 	 GHCND:USC00361572
# PLEASANTVILLE, TN US: 	 GHCND:USC00407300
# ELGIN 9.3 SSW, TX US: 	 GHCND:US1TXBST096
# LIVINGSTON 4.5 SSE, TX US: 	 GHCND:US1TXPL0002
# PARK CITY 5.5 NNE, UT US: 	 GHCND:US1UTSM0001
# FREELAND 2.5 ENE, WA US: 	 GHCND:US1WAIS0038
# NEW HOLSTEIN, WI US: 	 GHCND:USC00475910
# DENMARK WWTP, WI US: 	 GHCND:USC00472055
# DELIA, CA: 	 GHCND:CA003022060
# HANNA, CA: 	 GHCND:CA003023000
# ROLLYVIEW, CA: 	 GHCND:CA003015550
# WATERTON LAKES BAKER, CA: 	 GHCND:CA003056993
# KERSLEY 2, CA: 	 GHCND:CA001094127
# MIRAMICHI RCS, CA: 	 GHCND:CA008100989
# BRIDGETOWN, CA: 	 GHCND:CA008200596
# NEW GRAFTON, CA: 	 GHCND:CA008204000
# BLUE MOUNTAIN, CA: 	 GHCND:CA008200587
# MILFORD STATION, CA: 	 GHCND:CA008203567
# KEBLE, CA: 	 GHCND:CA008202580
# BROADVIEW, CA: 	 GHCND:CA00401I010
# GRASSWOOD, CA: 	 GHCND:CA004052956
# WELDON, CA: 	 GHCND:CA004058732
# MAYO ROAD, CA: 	 GHCND:CA002100709
# SAN LUIS, CO: 	 GHCND:COM00080370
# SAN ANTONIO DEL TACHIRA, VE: 	 GHCND:VEM00080447
# ANTONIO ROLDAN BETANCOURT, CO: 	 GHCND:COM00080084
# SAN JULIAN, CU: 	 GHCND:CUW00012857
# LA CONCORDIA, EC: 	 GHCND:ECM00084050
# MEADOW LAKE, CA US: 	 GHCND:USC00045496
# FAIRPLAY S PARK RD, CO US: 	 GHCND:USC00052816
# MUSE, FL US: 	 GHCND:USC00086048
# KEALIALALO HAWAII, HI US: 	 GHCND:USR0000HKLL
# HUDSON, IA US: 	 GHCND:USC00133964
# CASCADE RANGER STATION, ID US: 	 GHCND:USC00101524
# CHALLIS IDAHO, ID US: 	 GHCND:USR0000ICHL
# JULIAETTA 4.1 SSE, ID US: 	 GHCND:US1IDNP0001
# CHICAGO AURORA MUNICIPAL AIRPORT, IL US: 	 WBAN:04808
# PROPHETSTOWN, IL US: 	 GHCND:USC00117014
# COCKEYSVILLE 2 NE, MD US: 	 GHCND:USC00181960
# EDENVILLE, MI US: 	 GHCND:USC00202472
# COOK MUNICIPAL AIRPORT, MN US: 	 WBAN:54905
# HAWLEY 2 SW, MN US: 	 GHCND:USC00213588
# DETROIT LAKES, MN US: 	 WBAN:94962
# ALEXANDRIA 3.0 N, MN US: 	 GHCND:US1MNDS0001
# HENDERSON 1.4 NE, MN US: 	 GHCND:US1MNLS0015
# LAKEFIELD, MN US: 	 GHCND:USC00214453
# LAMBERTON SOUTHWEST RESEARCH AND OUTREACH CENTER, MN US: 	 GHCND:USC00214546
# LONG PRAIRIE, MN US: 	 GHCND:USC00214861
# VIRGINIA, MN US: 	 GHCND:USC00218543
# TAMARAC WILDLIFE REF, MN US: 	 GHCND:USC00218191
# TOWER 2 S, MN US: 	 GHCND:USC00218311
# FAIRMONT RADIO KSUM, MN US: 	 GHCND:USC00212702
# KIRKSVILLE, MO US: 	 GHCND:USC00234544
# SPRINGFIELD ELMWOOD, OH US: 	 GHCND:USC00337927
# DEER CREEK LAKE, OH US: 	 GHCND:USC00332090
# BERLIN LAKE, OH US: 	 GHCND:USC00330639
# STRONGSTOWN, PA US: 	 GHCND:USC00368589
# YORK SPRINGS 0.7 SE, PA US: 	 GHCND:US1PAAD0003
# SALEM 5.1 SSE, SC US: 	 GHCND:US1SCOC0039
# KIAWAH ISLAND 1.5 NE, SC US: 	 GHCND:US1SCCR0083
# OGLALA 1 S, SD US: 	 GHCND:USC00396227
# TENNESSEE NWR DUCK R, TN US: 	 GHCND:USC00408918
# CEDAR HILL 1.4 N, TX US: 	 GHCND:US1TXDA0050
# ENOSBURG FALLS, VT US: 	 GHCND:USC00432769
# KEWASKUM 1.8 WNW, WI US: 	 GHCND:US1WIWS0004
# FENNIMORE 1 NE, WI US: 	 GHCND:USC00472745
# SHEBOYGAN, WI US: 	 GHCND:USC00477725
# BELLA COOLA A, CA: 	 GHCND:CA001060841
# ATLIN, CA: 	 GHCND:CA001200560
# ELKFORD, CA: 	 GHCND:CA001152653
# PEACHLAND MINOS ROCK, CA: 	 GHCND:CA001126079
# WADHAMS CDF, CA: 	 GHCND:CA00106Q669
# NATAL KAISER RESOURCES, CA: 	 GHCND:CA001155403
# DENISON SHERIFF, CA: 	 GHCND:CA001182428
# CARMAN 2, CA: 	 GHCND:CA005020553
# CHARLO A, CA: 	 GHCND:CA008100880
# NAUWIGEWAUK, CA: 	 GHCND:CA008103441
# IRISHTOWN 3.4 NNW, CA: 	 GHCND:CA1NB000027
# TRACADIE, CA: 	 GHCND:CA008205895
# ASPY BAY 0.9 SW, CA: 	 GHCND:CA1NS000061
# CHETICAMP: 	 GHCND:CA008200824
# BURFORD 4.7 SE, CA: 	 GHCND:CA1ON000014
# CENTRETON, CA: 	 GHCND:CA006151307
# VAL RACINE, CA: 	 GHCND:CA007028695
# DAVIN 3, CA: 	 GHCND:CA004012162
# GRAYSON, CA: 	 GHCND:CA004012988
# QU APPELLE, CA: 	 GHCND:CA004016320
# EL PORVENIR, MX: 	 GHCND:MXN00020201
# EL CUALE, MX: 	 GHCND:MXN00014339
# DZILAM DE BRAVO, MX: 	 GHCND:MXN00031010
# KNOXVILLE 2.0 NE, AR US: 	 GHCND:US1ARJH0001
# MOUNT MAGAZINE, AR US: 	 GHCND:USC00035010
# GYPSUM COLORADO, CO US: 	 GHCND:USR0000CGYP
# MULLET KEY, US: 	 GHCND:USC00086040
# BLOXHAM FLORIDA, FL US: 	 GHCND:USR0000FBLO
# BUCKINGHAM 1.7 SE, FL US: 	 GHCND:US1FLLE0006
# ATLANTA 4.4 ENE, GA US: 	 GHCND:US1GAFT0042
# ROSWELL 3.0 ESE, GA US: 	 GHCND:US1GAFT0031
# LOST NATION 0.3 S, IA US: 	 GHCND:US1IACN0012
# KIRKWOOD 2 NW, IL US: 	 COOP:114764
# STERLING ROCK FALLS WHITESIDE CO JOSH BITTORF FIELD AIRPORT, IL US: 	 WBAN:04894
# KENDALLVILLE 0.2 W, IN US: 	 GHCND:US1INNB0013
# GREAT BEND 8.2 ENE, KS US: 	 GHCND:US1KSBT0014
# WAKEFIELD 0.2 NW, KS US: 	 GHCND:US1KSCY0008
# ELKTON, KY US: 	 GHCND:USC00152548
# SOUTHWEST HARBOR 3 S: 	 GHCND:USC00178301
# GRAYLING ARMY AIR FIELD AIRPORT, MI US: 	 WBAN:04878
# MACKINAW CITY 1.1 ENE, MI US: 	 GHCND:US1MICB0007
# DUNBAR FOREST EXPERIMENTAL ST, MI US: 	 GHCND:USC00202298
# THIEF LAKE REFUGE, MN US: 	 GHCND:USC00218235
# STAPLES MUNICIPAL AIRPORT, MN US: 	 WBAN:54910
# WAYAH NORTH CAROLINA, NC US: 	 GHCND:USR0000NWAY
# MILNESAND 0.0 W, NM US: 	 GHCND:US1NMRV0027
# SOUTH VALLEY 3.8 SSW, NM US: 	 GHCND:US1NMBR0072
# SULPHUR 2.5 WSW, OK US: 	 GHCND:US1OKMR0001
# NELSCOTT, OR US: 	 GHCND:USC00355980
# MADRAS 6.6 NNW, OR US: 	 GHCND:US1ORJF0001
# WHITESON 1 NW, OR US: 	 GHCND:USC00359298
# DAMASCUS 0.1 NE, PA US: 	 GHCND:US1PAWN0053
# FOX RUN 1.6 NNE, PA US: 	 GHCND:US1PABT0015
# MURFREESBORO SUBSTN, TN US: 	 GHCND:USC00406376
# LINDEN 7.9 NNW, TN US: 	 GHCND:US1TNPY0004
# HYDE PARK, VT US: 	 GHCND:USC00434075
# MIRROR FLETCHER, CA: 	 GHCND:CA003024572
# TROCHU WIMBORNE, CA: 	 GHCND:CA003026550
# HUXLEY EAST, CA: 	 GHCND:CA003023423
# WAINWRIGHT HEATH, CA: 	 GHCND:CA003016932
# STONEY MOUNTAIN LO, CA: 	 GHCND:CA003066160
# SYLVAN LAKE, CA: 	 GHCND:CA003026330
# MARKERVILLE, CA: 	 GHCND:CA003024210
# WETASKIWIN AGCM, CA: 	 GHCND:CA003017282
# WIMBORNE GAS PLANT, CA: 	 GHCND:CA003027580
# EVARTS, CA: 	 GHCND:CA003022485
# ARMSTRONG HULLCAR, CA: 	 GHCND:CA001160483
# HARROP, CA: 	 GHCND:CA001143338
# STUIE TWEEDSMUIR LODGE, CA: 	 GHCND:CA001067776
# BARKERVILLE, CA: 	 GHCND:CA001090660
# CARAQUET: 	 GHCND:CA008100785
# MISCOU ISLAND AUT: 	 GHCND:CA008103050
# PAQUETVILLE 1.2 ENE, CA: 	 GHCND:CA1NB000039
# ANNAPOLIS ROYAL: 	 GHCND:CA008200100
# POINTE DE L EGLISE, CA: 	 GHCND:CA008204459
# NAHANNI VALLEY, CA: 	 GHCND:CA002202727
# KUGLUKTUK CLIMATE, CA: 	 GHCND:CA002300904
# RIDEAU CANAL UPP BREWERS, CA: 	 GHCND:CA006107105
# KAPUSKASING A, CA: 	 GHCND:CA006073975
# BONNER LAKE, CA: 	 GHCND:CA006070QK6
# ORONO, CA: 	 GHCND:CA006155854
# FERNDALE, CA: 	 GHCND:CA006122405
# WARDSVILLE, CA: 	 GHCND:CA006139287
# MANIWAKI AIRPORT, CA: 	 GHCND:CA007034482
# ST AUGUSTIN, CA: 	 GHCND:CA007016900
# CRAVEN 4.6 E, CA: 	 GHCND:CA1SK000009
# NIPAWIN, CA: 	 GHCND:CA00407N51G
# TURTLEFORD, CA: 	 GHCND:CA004048240
# FRANCES LAKE, CA: 	 GHCND:CA002100611
# KLONDIKE, CA: 	 GHCND:CA002100679
# JOSE MARIA CORDOVA, CO: 	 GHCND:COM00080112
# LIBERIA, CS: 	 GHCND:CS000078774
# WILLOW BEACH, AZ US: 	 GHCND:USC00029376
# BAY LAKE 4.1 WSW, FL US: 	 GHCND:US1FLOR0035
# ST AUGUSTINE 10.1 SSE, FL US: 	 GHCND:US1FLSJ0012
# MCCALL AIRPORT, ID US: 	 WBAN:94182
# JACKSONVILLE 2.6 SE, IL US: 	 GHCND:US1ILMG0014
# K9EQT LOGANSPORT 3.9 NNW, IN US: 	 GHCND:US1INCS0013
# ROBSON, LA US: 	 GHCND:USC00167924
# MIDDLE RIVER, US: 	 GHCND:USC00185916
# ELY, MN US: 	 GHCND:USC00212561
# KENSINGTON 3.2 W, MN US: 	 GHCND:US1MNGR0002
# BROOKLYN 2 SE, MS US: 	 GHCND:USC00221098
# CELO, NC US: 	 GHCND:USC00311629
# ALMA 2.3 NNE, NE US: 	 GHCND:US10harl002
# LACEY TWP 6.3 E, NJ US: 	 GHCND:US1NJOC0017
# HUDSON, OH US: 	 GHCND:USC00333876
# BEND 17.1 SSW, OR US: 	 GHCND:US1ORDS0056
# MILLHEIM, PA US: 	 GHCND:USC00365790
# NORTH SCITUATE 4 W, RI US: 	 GHCND:USC00375354
# DOVER FIRE TOWER, TN US: 	 GHCND:USC00402585
# TRINIDAD POWER PLANT, TX US: 	 GHCND:USC00419137
# BOULDER, UT US: 	 GHCND:USC00420849
# CUMBERLAND 3.5 E, WI US: 	 GHCND:US1WIBR0022
# GRANTLEY ADAMS: 	 GHCND:BB000078954
# SAO LOURENCO DA MATA, BR: 	 GHCND:BR000835048
# GOLD ROCK CREEK, BF: 	 GHCND:BFW00012712
# WESTEROSE 2, CA: 	 GHCND:CA003017258
# EDGEWOOD, CA: 	 GHCND:CA001142640
# INGLIS, CA: 	 GHCND:CA005011360
# PETITCODIAC, CA: 	 GHCND:CA008103900
# IGLOOLIK, CA: 	 GHCND:CA002402540
# SYDENHAM, CA: 	 GHCND:CA006108195
# MISTINIKON LAKE DAM, CA: 	 GHCND:CA006075211
# GRIMSBY ALLAN, CA: 	 GHCND:CA006133050
# MILFORD 8.0 WSW CANWARN, CA: 	 GHCND:CA1ON000129
# ST EMILE DE SUFFOLK, CA: 	 GHCND:CA007037175
# CORONACH, CA: 	 GHCND:CA004031845
# CADILLAC, CA: 	 GHCND:CA007081002
# ALFONSO LOPEZ PUMAREJO, CO: 	 GHCND:COM00080036
# EL CRUCERO, MX: 	 GHCND:MXN00003182
# TINUN, MX: 	 GHCND:MXN00004059
# PLAN DE IGUALA, MX: 	 GHCND:MXN00007336
# COMALA, MX: 	 GHCND:MXN00006007
# CINCO SEORES, MX: 	 GHCND:MXN00011011
# ATENGO SMN, MX: 	 GHCND:MXN00014014
# PUEBLA DGE, MX: 	 GHCND:MXN00021035
# CROWN POINT AIRPORT TOBAGO, TD: 	 GHCND:TDM00078962
# GREEN MOUNTAIN, AR US: 	 GHCND:USC00032952
# CALIFORNIA CITY 11.9 WSW, CA US: 	 GHCND:US1CAKN0002
# MADISON CENTER 1.8 W, CT US: 	 GHCND:US1CTNH0005
# FORT WAYNE INTERNATIONAL AIRPORT, IN US: 	 WBAN:14827
# BERNE 0.8 WSW, IN US: 	 GHCND:US1INAD0001
# HASTINGS, MI US: 	 GHCND:USC00203661
# MENTOR 2.5 SSW, MN US: 	 GHCND:US1MNPK0015
# RAYMONDVILLE 7.5 NE, MO US: 	 GHCND:US1MOTX0042
# BONNERS FERRY, ID US: 	 GHCND:USC00101079
# ARARAT 4.7 SW, NC US: 	 GHCND:US1NCSR0006
# LOS ALAMOS, NM US: 	 GHCND:USC00295084
# HALFWAY, OR US: 	 GHCND:USC00353604
# GARDINER 1 N, OR US: 	 GHCND:USC00353193
# LEBANON 1.8 NNW, OR US: 	 GHCND:US1ORLN0082
# GREATER PITTSBURGH AFB, PA US: 	 GHCND:USW00014809
# HOUSTON 3.9 SE, TX US: 	 GHCND:US1TXHRR069
# JARVIE HAMLET, CA: 	 GHCND:CA003063517
# RYCROFT AGCM, CA: 	 GHCND:CA003075601
# WHITESHELL 1.3 NE, CA: 	 GHCND:CA1MB000368
# CLOYNE ONT HYDRO, CA: 	 GHCND:CA006161662
# MILLER LAKE FOREST, CA: 	 GHCND:CA006125155
# BRUCE MINES, CA: 	 GHCND:CA006051027
# RICHMOND, CA: 	 GHCND:CA007026465
# FORT COULONGE, CA: 	 GHCND:CA007032440
# LEROY, CA: 	 GHCND:CA004014322
# MELFORT, CA: 	 GHCND:CA004055080
# VENUSTIANO CARRANZA, MX: 	 GHCND:MXN00021142
# TOPO CHICO, MX: 	 GHCND:MXN00019061
# CENTRAL VALLARTA, MX: 	 GHCND:MXN00023166
# ACATITAN, MX: 	 GHCND:MXN00025001
# ESCUELA DE BIOLOGIA U.A.S., MX: 	 GHCND:MXN00025102
# SAN DIONISIO, NU: 	 GHCND:NU000055016
# PUNTA DE PIEDRAS, VE: 	 GHCND:VE000001740
# VIEQUES 1.1 WSW, US: 	 GHCND:RQ1PRVQ0001
# HOONAH SEAPLANE BASE, AK US: 	 WBAN:25378
# GLENEAGLE 2.2 SSE, CO US: 	 GHCND:US1COEP0255
# EVERGLADES CITY 5 NE, FL US: 	 WBAN:92826
# BOCA RATON 3.8 WSW, FL US: 	 GHCND:US1FLPB0080
# BITHLO, FL US: 	 GHCND:USC00081565
# HILO INTERNATIONAL AIRPORT 87, HI US: 	 WBAN:21504
# HANA 354, US: 	 GHCND:USC00511122
# ATLANTIC 5 SW, IA US: 	 GHCND:USC00130372
# WINTERSET 0.2 NNW, IA US: 	 GHCND:US1IAMD0004
# MARION RESERVOIR, KS US: 	 GHCND:USC00145039
# UNION 3.0 W, KY US: 	 GHCND:US1KYBN0009
# CADDO, KY US: 	 GHCND:USC00151194
# MUNFORDVILLE 5 NW, KY US: 	 GHCND:USC00155684
# MILLERSTOWN, KY US: 	 GHCND:USC00155438
# PARADISE STEAM PLANT, KY US: 	 GHCND:USC00156155
# SHELBYVILLE 3.2 E, KY US: 	 GHCND:US1KYSH0002
# OWENSBORO 3.4 NW, KY US: 	 GHCND:US1KYDV0009
# SCOTTSVILLE 6.2 SSW, KY US: 	 GHCND:US1KYAL0007
# MARKLAND DAM 39, IN US: 	 GHCND:USC00125381
# KAPLIN 8 S, LA US: 	 GHCND:USC00164785
# GRAND LAKE STREAM, ME US: 	 GHCND:USC00173261
# GRANITE FALLS, MN US: 	 GHCND:USC00213311
# ASTORIA 2.2 SSE, SD US: 	 GHCND:US1SDBK0002
# SHERIDAN 1.4 ENE, MT US: 	 GHCND:US1MTMD0003
# BARADA 3 SW, NE US: 	 GHCND:USC00250470
# PAHRANAGAT WILDLIFE REFUGE, NV US: 	 GHCND:USC00265880
# WINNEMUCCA AIRPORT, NV US: 	 WBAN:24128
# UPPER SANDUSKY W WKS, OH US: 	 GHCND:USC00338539
# SHERWOOD 3.3 SE, OR US: 	 GHCND:US1ORCC0063
# MERCER, PA US: 	 GHCND:USC00365651
# MOUNT JULIET 8.2 E, TN US: 	 GHCND:US1TNWN0075
# KILEEN FORT HOOD S ARMY AIR FIELD, TX US: 	 GHCND:USW00013955
# POINT COMFORT 0.8 N, TX US: 	 GHCND:US1TXCLH010
# PORT O CONNOR, TX US: 	 GHCND:USC00417186
# SAN MARCOS 2.9 WNW, TX US: 	 GHCND:US1TXHYS019
# KILMARNOCK 1 N, VA US: 	 GHCND:USC00444600
# WATERBURY 3.4 NNE, VT US: 	 GHCND:US1VTWS0002
# PINE PASS, CA: 	 GHCND:CA001186171
# HARDWOOD RIDGE, CA: 	 GHCND:CA008102160
# MOOSE JAW 2.4 WSW, CA: 	 GHCND:CA1SK000008
# MILDRED, CA: 	 GHCND:CA004065172
# EL CARANO, CO: 	 GHCND:COM00080144
# FINCA LA PATRIA, MX: 	 GHCND:MXN00007187
# MEOQUI DGE, MX: 	 GHCND:MXN00008019
# LAS BRISAS, MX: 	 GHCND:MXN00019163
# PUERTO MADERO, MX: 	 GHCND:MXN00007136
# AHUALULCO DE MERCADO DGE, MX: 	 GHCND:MXN00014333
# CONAFRUT LOS CUES, MX: 	 GHCND:MXN00022061
# HERMOSILLO II DGE, MX: 	 GHCND:MXN00026139
# TUXPAN.VER., MX: 	 GHCND:MXM00076640
# CORINTO: 	 GHCND:NUW00011803
# PONCE 5.0 NNW, US: 	 GHCND:RQ1PRPC0004
# BLAKELY MOUNTAIN DAM, AR US: 	 GHCND:USC00030764
# ROOSEVELT ARIZONA, AZ US: 	 GHCND:USR0000AROO
# MERCED FALLS, CA US: 	 GHCND:USC00045541
# TERRA BELLA 6.3 W, CA US: 	 GHCND:US1CATL0004
# LAKELAND 13.6 N, FL US: 	 GHCND:US1FLPK0066
# FELDA, FL US: 	 GHCND:USC00082923
# DARIEN 9.0 ENE, GA US: 	 GHCND:US1GAMI0006
# AMBOY, IL US: 	 GHCND:USC00110146
# GILBERTS 0.8 W, IL US: 	 GHCND:US1ILKN0087
# N900A FARMLAND 2.5 NNE, IN US: 	 GHCND:US1INRN0005
# GREENFIELD 0.1 SW, IN US: 	 GHCND:US1INHN0017
# PETERSBURG 1.4 ENE, IN US: 	 GHCND:US1INPK0001
# FILLMORE 3.1 NNW, IN US: 	 GHCND:US1INPM0003
# FORT LEAVENWORTH SHERMAN AFB, KS US: 	 GHCND:USW00013921
# BARREN RIVER LAKE, KY US: 	 GHCND:USC00150422
# EMINENCE, KY US: 	 GHCND:US1KYHY0005
# HART 3 WSW, MI US: 	 GHCND:US1MIOC0003
# RUDYARD 4 N, MI US: 	 GHCND:USC00207190
# SARTELL 2.6 SW, MN US: 	 GHCND:US1MNSR0033
# GRETNA 0.1 SSE, NE US: 	 GHCND:US1NESY0009
# DUFURRENA DENIO 22 WSW, NV US: 	 GHCND:USC00268776
# BEERSTON, NY US: 	 GHCND:USC00300540
# WASHINGTON 3 SSW, VA US: 	 GHCND:USC00448902
# CHEHALIS 0.0 N, WA US: 	 GHCND:US1WALW0029

# %%
station_types
# Out:
# {'WBAN': 229, 'GHCND': 4793, 'COOP': 59, 'NEXRAD': 12}

# %%
# Create Station-IDs-of-Interest Listing

# %%
with open("station_ids_of_interest.csv","w") as fh_stoi:

    for stn_name in unique_closest_station:
        if stn_name not in mapper__name_to_id:
            print(f"WARN: {stn_name} not found on current NOAA Stations Listing")
        else:
            stn_id = mapper__name_to_id[stn_name]
            year_start = mapper__id_to_activeyears[stn_id][0]
            year_ended = mapper__id_to_activeyears[stn_id][1]
            stn_name = mapper__id_to_name[]
            fh_stoi.write(f"{stn_id},{year_start},{year_ended}\n")
# Out:
# WARN: UTQIAGVIK FORMERLY BARROW 4 ENE, AK US not found on current NOAA Stations Listing

# %%
# !head station_ids_of_interest.csv
# Out:
# WBAN:54777,2005,2019
# GHCND:USC00191097,1884,1951
# GHCND:US1NYSF0076,2016,2019
# GHCND:USC00362116,1951,1988
# GHCND:US1ILRI0018,2016,2019
# GHCND:USC00369464,1893,2017
# GHCND:USC00303464,1958,2015
# GHCND:US1PAMT0089,2015,2019
# GHCND:USC00191099,1890,1896
# GHCND:US1PABR0009,2007,2018
